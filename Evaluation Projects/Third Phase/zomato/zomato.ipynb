# %%
# import header files
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#read dataset file
d=pd.read_csv('zomatoo.csv',encoding="latin-1")
d.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
#read second data set
d2 = pd.read_excel("Country-Code.xlsx")
d2.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
#lets merge both dataset to start analysing
df=pd.merge(d,d2,on='Country Code',how='left')

# %% [markdown]
# ## Statistical Alalysis

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df1.tail()
# Out:
#       Restaurant ID  Restaurant Name  Country Code  City  Address  Locality  \
# 9546        5915730             4443           208   140     5926       517
# 9547        5908749             1311           208   140     5962       552
# 9548        5915807             3069           208   140     5966       554
# 9549        5916112              513           208   140     5967       554
# 9550        5927402             7240           208   140     4258       670
#
#       Locality Verbose  Longitude   Latitude  Cuisines  ...  \
# 9546               523  28.977392  41.022793      1814  ...
# 9547               558  29.041297  41.009847      1825  ...
# 9548               561  29.034640  41.055817      1110  ...
# 9549               561  29.036019  41.057979      1658  ...
# 9550               681  29.026016  40.984776       331  ...
#
#       Has Table booking  Has Online delivery  Is delivering now  \
# 9546                  0                    0                  0
# ...

# %%
df.shape
# Out:
# (9551, 22)

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %% [raw]
# *There are 22 columns and 9551 rows in dataset
# *It consist of three datatypes int,float and object

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
#describe data using heatmap
plt.figure(figsize=(12,16))
sns.heatmap(df.describe(),fmt='0.1f',annot = True,cmap='twilight_shifted')
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
#null value
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %% [markdown]
# Null values present

# %%
# filling the missing values in Cuisines column with NaN

df['Cuisines'] = df['Cuisines'].fillna('NaN')

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %% [markdown]
# null values are removed

# %%
#missing values
df.isin([' ','NA','-']).sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
country_name=df.Country.value_counts().index
country_value=df.Country.value_counts().values

# %% [markdown]
# # Data Visualisation

# %% [markdown]
# ## univariant analysis

# %%
plt.pie(country_value[:3],labels=country_name[:3],autopct='%1.3f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2119d4db730>,
# ...
#  [Text(-1.0829742700952103, 0.19278674827836725, 'India'),
#   Text(1.077281715838356, -0.22240527134123297, 'United States'),
#   Text(1.0995865153823035, -0.03015783794312073, 'United Kingdom')],
#  [Text(-0.590713238233751, 0.10515640815183668, '94.392%'),
#   Text(0.5876082086391032, -0.12131196618612707, '4.735%'),
#   Text(0.5997744629358018, -0.01644972978715676, '0.873%')])

# %%
city_value=df.City.value_counts().values
city_labels=df.City.value_counts().index

# %%
plt.pie(city_value[:5],labels=city_labels[:5],autopct='%1.3f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2119d563880>,
# ...
#  [Text(-0.6145352824185932, 0.9123301960708633, 'New Delhi'),
#   Text(0.0623675251198054, -1.0982305276263407, 'Gurgaon'),
#   Text(0.8789045225625368, -0.6614581167535246, 'Noida'),
#   Text(1.0922218418223437, -0.13058119407559224, 'Faridabad'),
#   Text(1.099946280005612, -0.010871113182029924, 'Ghaziabad')],
#  [Text(-0.3352010631374145, 0.497634652402289, '68.869%'),
#   Text(0.0340186500653484, -0.5990348332507311, '14.068%'),
#   Text(0.47940246685229276, -0.36079533641101336, '13.590%'),
#   Text(0.5957573682667329, -0.07122610585941394, '3.158%'),
#   Text(0.5999706981848791, -0.005929698099289049, '0.315%')])

# %% [markdown]
# This pie chart clearly visualises that Zomato is India based, as India accounts for 94.3% of the total restaurants listed on Zomato in the whole world. United States is second with only 4.7% of the total number of restaurants. We can also almost vaguely and roughly assume that Zomato is an Indian company

# %%
cuisines=df['Cuisines'].value_counts()[:10]
x = sns.barplot(cuisines, cuisines.index, palette="RdBu")

# %% [markdown]
# Most bought cuisines is nortyh indian

# %%
c=df['Currency'].value_counts()[:10]
x = sns.barplot(c, c.index, palette="RdBu")

# %%
sns.countplot(df['Has Online delivery'], saturation = 1.5)
# Out:
# <AxesSubplot:xlabel='Has Online delivery', ylabel='count'>

# %% [markdown]
# Most of the restaurent dont have online delivery

# %%
sns.countplot(df['Has Table booking'], saturation = 1.5)
# Out:
# <AxesSubplot:xlabel='Has Table booking', ylabel='count'>

# %% [markdown]
# Most of the restaurent dont have table booking

# %%
sns.countplot(df['Price range'])
# Out:
# <AxesSubplot:xlabel='Price range', ylabel='count'>

# %% [markdown]
# highest price range is marked with 1 descending numerically

# %%
plt.figure(figsize=(9,7))

sns.distplot(df['Votes'],bins=20)
# Out:
# <AxesSubplot:xlabel='Votes', ylabel='Density'>

# %%
plt.figure(figsize=(12,16))
sns.countplot(df['Aggregate rating'])
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='count'>

# %% [markdown]
# Highest rating is between 2.9to 3.9

# %% [markdown]
# ## Bivariant analysis

# %%
ratings=df.groupby(['Aggregate rating','Rating color','Rating text']).size().reset_index().rename(columns={0:'Rating counts'})
ratings
# Out:
#     Aggregate rating Rating color Rating text  Rating counts
# 0                0.0        White   Not rated           2148
# 1                1.8          Red        Poor              1
# 2                1.9          Red        Poor              2
# 3                2.0          Red        Poor              7
# 4                2.1          Red        Poor             15
# 5                2.2          Red        Poor             27
# 6                2.3          Red        Poor             47
# 7                2.4          Red        Poor             87
# 8                2.5       Orange     Average            110
# 9                2.6       Orange     Average            191
# 10               2.7       Orange     Average            250
# 11               2.8       Orange     Average            315
# 12               2.9       Orange     Average            381
# 13               3.0       Orange     Average            468
# ...

# %% [raw]
# when rating is between 4.5 to 4.9 --------------->Excellent
# when rating is between 4.0 to 4.4--------------->very good
# when rating is between 3.5to 3.9--------------->good
# when rating is between 3.0 to 3.4--------------->average
# when rating is between 2.5 to 2.9--------------->average
# when rating is between 2.0 to 2.4--------------->poor

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Aggregate rating',y='Rating counts',data=ratings)
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Rating counts'>

# %%
plt.figure(figsize=(12,6))
ax = sns.countplot(y= "Country", hue="Has Online delivery", data=df)

# %% [markdown]
# India and uae are only country with online delivery

# %%
df.groupby(['Country','Has Online delivery']).size().reset_index()
# Out:
#            Country Has Online delivery     0
# 0        Australia                  No    24
# 1           Brazil                  No    60
# 2           Canada                  No     4
# 3            India                  No  6229
# 4            India                 Yes  2423
# 5        Indonesia                  No    21
# 6      New Zealand                  No    40
# 7      Phillipines                  No    22
# 8            Qatar                  No    20
# 9        Singapore                  No    20
# 10    South Africa                  No    60
# 11       Sri Lanka                  No    20
# 12          Turkey                  No    34
# 13             UAE                  No    32
# 14             UAE                 Yes    28
# 15  United Kingdom                  No    80
# 16   United States                  No   434

# %% [markdown]
# ## Multi variant analysis

# %%
#palette is used to give color as per your reqiirement or color mapping
plt.figure(figsize=(12,6))
sns.barplot(x='Aggregate rating',y='Rating counts',data=ratings,hue='Rating color',palette=['beige','red','orange','yellow','green','green'])
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Rating counts'>

# %%
df.groupby(['Country','Currency']).size().reset_index()
# Out:
#            Country                Currency     0
# 0        Australia               Dollar($)    24
# 1           Brazil      Brazilian Real(R$)    60
# 2           Canada               Dollar($)     4
# 3            India      Indian Rupees(Rs.)  8652
# 4        Indonesia  Indonesian Rupiah(IDR)    21
# 5      New Zealand           NewZealand($)    40
# 6      Phillipines        Botswana Pula(P)    22
# 7            Qatar         Qatari Rial(QR)    20
# 8        Singapore               Dollar($)    20
# 9     South Africa                 Rand(R)    60
# 10       Sri Lanka   Sri Lankan Rupee(LKR)    20
# 11          Turkey        Turkish Lira(TL)    34
# 12             UAE      Emirati Diram(AED)    60
# 13  United Kingdom              Pounds(£)    80
# 14   United States               Dollar($)   434

# %%
df[(df['Average Cost for two']<10000) & (df['Aggregate rating']!=0)].plot.scatter(x = 'Average Cost for two', y = 'Aggregate rating', figsize=(15,7), title="The dependence of the rating on the price for two")
plt.show()

# %%
plt.figure(figsize=(10,10))

ax=df.Average_Cost_for_two.value_counts()[:10]
label=df['Average_Cost_for_two'].value_counts()[:10].index

plt.pie(ax,labels=label,autopct='%.2f')

plt.title("'Average cost for two",fontsize=25)
plt.show()

# %%
df[(df['Average Cost for two']<10000) & (df['Currency']!=0)].plot.scatter(x = 'Average Cost for two', y = 'Currency', figsize=(15,7), title="The dependence of the rating on the price for two")
plt.show()

# %% [markdown]
# There is 17.86% percetage chances that for two person average cost will be 400 and 17.04% chance that cost will be 300. so on

# %%
df[(df['Average Cost for two']<10000) & (df['Price range']!=0)].plot.scatter(x = 'Average Cost for two', y = 'Price range', figsize=(15,7), title="The dependence of the rating on the price for two")
plt.show()

# %% [markdown]
# This graph shows us how the Price range is distributed around the aggregrate rating. The maximum number of restaurants falls in the 0 - 1000 price range and 2.5 to 4.0 rating
#
# As price range increses Average Cost Also increases

# %% [markdown]
# ## Seprating numerical and categorical data

# %%
category=[]
for i in df.dtypes.index:
    if df.dtypes[i]=='object':
        category.append(i)
print(len(category))
category
# Out:
# 14
# ['Restaurant Name',
#  'City',
#  'Address',
#  'Locality',
#  'Locality Verbose',
#  'Cuisines',
#  'Currency',
#  'Has Table booking',
#  'Has Online delivery',
#  'Is delivering now',
#  'Switch to order menu',
#  'Rating color',
#  'Rating text',
#  'Country']

# %%
numerical=[]
for j in df.dtypes.index:
    if df.dtypes[j]!='object':
        numerical.append(j)
print(len(numerical))
numerical
# Out:
# 8
# ['Restaurant ID',
#  'Country Code',
#  'Longitude',
#  'Latitude',
#  'Average Cost for two',
#  'Price range',
#  'Aggregate rating',
#  'Votes']

# %% [markdown]
# ## Encoding categorical data

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in category:
    df[i] = le.fit_transform(df[i])
df.head()
# Out:
#    Restaurant ID  Restaurant Name  Country Code  City  Address  Locality  \
# 0        6317637             3749           162    73     8685       171
# 1        6304287             3173           162    73     6055       593
# 2        6300002             2897           162    75     4684       308
# 3        6318506             4707           162    75     8690       862
# 4        6314302             5523           162    75     8689       862
#
#    Locality Verbose   Longitude   Latitude  Cuisines  ...  Has Table booking  \
# 0               172  121.027535  14.565443       920  ...                  1
# 1               601  121.014101  14.553708      1111  ...                  1
# 2               314  121.056831  14.581404      1672  ...                  1
# 3               875  121.056475  14.585318      1126  ...                  0
# 4               875  121.057508  14.584450      1122  ...                  1
#
# ...

# %% [markdown]
# caregorical data is encoded

# %%
df1=df.copy()
df2=df.copy()
df3=df2.copy()

# %% [markdown]
# ## Feature selection and Engineering

# %% [markdown]
# ## 1. Outliers Detection and Removal

# %%
plt.figure(figsize=(18,10),facecolor='white')
plotnumber=1

for column in numerical:
    if plotnumber<=6:
        ax=plt.subplot(2,3,plotnumber)
        sns.boxplot(df[column],color='pink')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# outliners are present

# %%
#using z-score
from scipy.stats import zscore
z = np.abs(zscore(df))
threshold = 3
df = df1[(z<3).all(axis = 1)]

# %%
df.shape
# Out:
# (9551, 22)

# %% [markdown]
# ## 2. Skewness Detection and Removal

# %%
df.skew()
# Out:
# Restaurant ID            0.061570
# Restaurant Name          0.044637
# Country Code             3.043965
# City                    -1.193777
# Address                 -0.040407
# Locality                -0.253554
# Locality Verbose        -0.183064
# Longitude               -2.807328
# Latitude                -3.081635
# Cuisines                -0.306726
# Average Cost for two    35.477915
# Currency                 2.858093
# Has Table booking        2.321100
# Has Online delivery      1.114620
# Is delivering now       16.673412
# Switch to order menu     0.000000
# Price range              0.889618
# Aggregate rating        -0.954130
# Rating color             0.046009
# Rating text              0.431408
# Votes                    8.807637
# Country                  3.312721
# dtype: float64

# %%
from sklearn.preprocessing  import power_transform, PowerTransformer
co=['Longitude','Latitude','Aggregate rating','Average Cost for two','Price range']
df[co]=power_transform(df[co],method='yeo-johnson')
df[co]
# Out:
#       Longitude  Latitude  Aggregate rating  Average Cost for two  Price range
# 0      2.498033 -1.602771          1.833264              0.974401     1.284171
# 1      2.497306 -1.603989          1.506121              1.060687     1.284171
# 2      2.499617 -1.601115          1.400030              2.302484     1.706541
# 3      2.499598 -1.600709          1.945248              1.284065     1.706541
# 4      2.499653 -1.600799          1.833264              1.284065     1.706541
# ...         ...       ...               ...                   ...          ...
# 9546  -1.640540  2.270905          1.090715             -1.416818     1.284171
# 9547  -1.638445  2.268528          1.192320             -1.187274     1.284171
# 9548  -1.638664  2.276969          0.699460             -0.769920     1.706541
# 9549  -1.638619  2.277366          0.990620             -1.072964     1.706541
# 9550  -1.638946  2.263927          0.990620             -1.725820     0.548245
#
# [9551 rows x 5 columns]

# %%
df.skew()
# Out:
# Restaurant ID            0.061570
# Restaurant Name          0.044637
# Country Code             3.043965
# City                    -1.193777
# Address                 -0.040407
# Locality                -0.253554
# Locality Verbose        -0.183064
# Longitude               -0.803832
# Latitude                -0.293200
# Cuisines                -0.306726
# Average Cost for two     0.142365
# Currency                 2.858093
# Has Table booking        2.321100
# Has Online delivery      1.114620
# Is delivering now       16.673412
# Switch to order menu     0.000000
# Price range              0.182963
# Aggregate rating        -0.610806
# Rating color             0.046009
# Rating text              0.431408
# Votes                    8.807637
# Country                  3.312721
# dtype: float64

# %% [markdown]
# we avoid categorical data

# %% [markdown]
# ## 3.Detection and removal of Corrleation

# %%
df.corr()
# Out:
#                       Restaurant ID  Restaurant Name  Country Code      City  \
# Restaurant ID              1.000000         0.003999      0.148471 -0.005844
# Restaurant Name            0.003999         1.000000      0.020012 -0.001399
# Country Code               0.148471         0.020012      1.000000 -0.181728
# City                      -0.005844        -0.001399     -0.181728  1.000000
# Address                    0.080615         0.000763     -0.220342 -0.019763
# Locality                   0.069511         0.004322     -0.120075  0.096444
# Locality Verbose           0.070102         0.004281     -0.117543  0.093142
# Longitude                 -0.193456         0.000176     -0.515263  0.110062
# Latitude                  -0.033866         0.013702      0.251772 -0.039338
# Cuisines                  -0.078669         0.051705     -0.133034  0.026646
# Average Cost for two      -0.202508         0.036941     -0.519488  0.037831
# ...

# %%
plt.figure(figsize=(25,15))
sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True, square=True, fmt='0.3f', 
            annot_kws={'size':10}, cmap="PiYG")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
#correlation in barplot
plt.figure(figsize = (18,6))
df.corr()['Average Cost for two'].drop(['Average Cost for two']).sort_values(ascending=False).plot(kind='bar',color = 'r')
plt.xlabel('Features',fontsize=15)
plt.ylabel('Income',fontsize=15)
plt.title('Correlation of features with Target Variable Income',fontsize = 18)
plt.show()

# %% [markdown]
# ## Detection multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif= pd.DataFrame()
vif['VIF']= [variance_inflation_factor(df.values,i) for i in range(df.shape[1])]
vif['Features']= df.columns
vif
# Out:
#             VIF              Features
# 0      2.638187         Restaurant ID
# 1      3.872671       Restaurant Name
# 2     18.714401          Country Code
# 3     11.759739                  City
# 4      4.419416               Address
# 5   5071.839986              Locality
# 6   4906.349373      Locality Verbose
# 7      2.006800             Longitude
# 8      1.642396              Latitude
# 9      4.828116              Cuisines
# 10     3.308785  Average Cost for two
# 11    15.366423              Currency
# 12     1.607564     Has Table booking
# 13     1.565571   Has Online delivery
# 14     1.018306     Is delivering now
# 15          NaN  Switch to order menu
# 16     2.648668           Price range
# 17     1.912041      Aggregate rating
# 18     5.953844          Rating color
# 19     2.774216           Rating text
# 20     1.493158                 Votes
# 21    53.842530               Country

# %% [markdown]
# *multi collinearity is present .Removing Some of highly correlated features. But this will not work here as most of input features are correlated with each other either moderated or poorly.
# *let's apply pca technique

# %%
# remane column
df.rename(columns = {'Average Cost for two':'Average_Cost_for_two'}, inplace = True)

# %%
#checking if target variable is balanced
df.Average_Cost_for_two.value_counts()
# Out:
# 500       900
# 300       897
# 400       857
# 200       687
# 600       652
#          ...
# 8000        1
# 2350        1
# 150000      1
# 70000       1
# 545         1
# Name: Average_Cost_for_two, Length: 140, dtype: int64

# %%
#SMOTE
from imblearn.over_sampling import SMOTE
X = df.drop(['Average_Cost_for_two'], axis =1)
Y = df['Average_Cost_for_two']

# %% [raw]
# *target variable is imblanced.
# *applying smote method to balance it

# %%
s = SMOTE()
X, Y = s.fit_resample(X, Y)

# %% [markdown]
# target variable is balanced

# %% [markdown]
# ## Scaling data

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_scale = scaler.fit_transform(X)

# %%
# apply pca
from sklearn.decomposition import PCA
pca = PCA()
#plot the graph to find the principal components
x_pca = pca.fit_transform(X_scale)
plt.figure(figsize=(10,10))
plt.plot(np.cumsum(pca.explained_variance_ratio_), 'ro-')
plt.xlabel('Number of Components')
plt.ylabel('Variance %')
plt.title('Explained variance Ratio')
plt.grid()

# %%
pca_new = PCA(n_components=20)
x_new = pca_new.fit_transform(X_scale)

# %%
principle_x=pd.DataFrame(x_new,columns=np.arange(20))

# %% [markdown]
# ## Regression Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import  GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import  Ridge
from sklearn.linear_model import  Lasso

# %%
X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=42, test_size=.33)

# %% [markdown]
# ## Finding best random state

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
maxR2_score=0
maxRS=0
for i in range(1,500):
    X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=i, test_size=.33)
    lin_reg=LinearRegression()
    lin_reg.fit(X_train,Y_train)
    y_pred=lin_reg.predict(X_test)
    R2=r2_score(Y_test,y_pred)
    if R2>maxR2_score:
        maxR2_score=R2
        maxRS=i
print('Best R2 Score is', maxR2_score ,'on Random_state', maxRS)
# Out:
# Best R2 Score is 0.7775219983134809 on Random_state 371

# %%
from sklearn.model_selection import cross_val_score

# %%
lr=LinearRegression()
rf = RandomForestRegressor()
dtc = DecisionTreeRegressor()
XT = ExtraTreesRegressor()
BR = BaggingRegressor()
adb=AdaBoostRegressor()
gradb=GradientBoostingRegressor()
model = [lr,rf,XT,dtc,adb,gradb]

for m in model:
    m.fit(X_train,Y_train)
    m.score(X_train,Y_train)
    y_pred = m.predict(X_test)

    print('\033[1m'+' R2 Score :'+'\033[0m')
    print(r2_score(Y_test,y_pred)) 
    print('==============================================================================================================')
# Out:
#  R2 Score :
# 0.039240259898572716
# ...
#  R2 Score :
# 0.40141512845289107
# ...
#  R2 Score :
# 0.5125013609804023
# ...
#  R2 Score :
# -0.0680009056219002
# ...
#  R2 Score :
# 0.5056401787669769
# ...
#  R2 Score :
# 0.31150498291048645
# ...

# %%
# Cross Validation
model = [lr,rf,XT,dtc,adb,gradb]

for m in model:
    score = cross_val_score(m, X_scale, Y, cv =5)
    print('\n')
    print('\033[1m'+'Cross Validation Score :',m,":"+'\033[0m\n')
    print("Mean CV Score :",score.mean())
    print('==============================================================================================================')
# Out:
# Cross Validation Score : LinearRegression() :
#
# Mean CV Score : 0.4278280772670768
# ...
#
#
# Cross Validation Score : RandomForestRegressor() :
#
# Mean CV Score : 0.5986864071223257
# ...
#
#
# Cross Validation Score : ExtraTreesRegressor() :
#
# Mean CV Score : 0.6444651239938567
# ...
#
#
# Cross Validation Score : DecisionTreeRegressor() :
#
# Mean CV Score : -0.9522115602107233
# ...
#
#
# Cross Validation Score : AdaBoostRegressor() :
#
# Mean CV Score : 0.4467034616725828
# ...
#
#
# Cross Validation Score : GradientBoostingRegressor() :
#
# Mean CV Score : 0.6113163531212236
# ...

# %% [markdown]
# ## Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter = {'n_estimators':[70],'max_depth': [25],
            'criterion':['mse','mae'],'min_samples_leaf': [5,10],
             'min_samples_split':[5,10],
             'max_features':["auto","sqrt"]}

# %%
parameter = {'n_estimators':[70],'max_depth': [25],
            'criterion':['mae'],'min_samples_leaf': [5,10],
             'min_samples_split':[5,10],
             'max_features':["auto","sqrt"]}

# %%
GCV = GridSearchCV(RandomForestRegressor(),parameter,cv=3,n_jobs = -1,verbose=3)

# %%
GCV.fit(X_train,Y_train)
# Out:
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# GridSearchCV(cv=3, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['mse', 'mae'], 'max_depth': [25],
#                          'max_features': ['auto', 'sqrt'],
#                          'min_samples_leaf': [5, 10],
#                          'min_samples_split': [5, 10], 'n_estimators': [70]},
#              verbose=3)

# %%
GCV.best_params_
# Out:
# {'criterion': 'mse',
#  'max_depth': 25,
#  'max_features': 'auto',
#  'min_samples_leaf': 5,
#  'min_samples_split': 10,
#  'n_estimators': 70}

# %% [markdown]
# ## Final Model

# %%
Final = RandomForestRegressor(criterion='mse',max_depth= 25,max_features= 'auto',min_samples_leaf= 5,min_samples_split= 10,n_estimators= 70)
Final.fit(X_train,Y_train)
y_pred=Final.predict(X_test)

print('accuracy')
print(r2_score(Y_test,y_pred)) 
print('\n')
# Out:
# accuracy
# 0.5411597975014233

# %%
plt.figure(figsize=(20,9))
y_pred=Final.predict(X_test)
sns.scatterplot(Y_test.round(2), y_pred)
print(' True Values Vs Predicted Value plot :')
plt.xlabel('True Values' , fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.tight_layout()
# Out:
#  True Values Vs Predicted Value plot :

# %%
import joblib
joblib.dump(Final,'cost of two.pkl')
# Out:
# ['cost of two.pkl']

# %% [markdown]
# # 2) Price range

# %%
#remane column
df.rename(columns = {'Price range':'Price_range'}, inplace = True)

# %%
#checking target variable for balance
df.Price_range.value_counts()
# Out:
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: Price_range, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
X = df.drop(['Price_range'], axis =1)
Y = df['Price_range']

# %%
s = SMOTE()
X, Y = s.fit_resample(X, Y)

# %% [markdown]
# ## Scaling data

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_scale = scaler.fit_transform(X)

# %%
#pca 
from sklearn.decomposition import PCA
pca = PCA()
#plot the graph to find the principal components
x_pca = pca.fit_transform(X_scale)
plt.figure(figsize=(10,10))
plt.plot(np.cumsum(pca.explained_variance_ratio_), 'ro-')
plt.xlabel('Number of Components')
plt.ylabel('Variance %')
plt.title('Explained variance Ratio')
plt.grid()

# %%
pca_new = PCA(n_components=20)
x_new = pca_new.fit_transform(X_scale)
x=pd.DataFrame(x_new,columns=np.arange(20))

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif= pd.DataFrame()
vif['VIF']= [variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
vif['Features']= x.columns
vif
# Out:
#     VIF  Features
# 0   1.0         0
# 1   1.0         1
# 2   1.0         2
# 3   1.0         3
# 4   1.0         4
# 5   1.0         5
# 6   1.0         6
# 7   1.0         7
# 8   1.0         8
# 9   1.0         9
# 10  1.0        10
# 11  1.0        11
# 12  1.0        12
# 13  1.0        13
# 14  1.0        14
# 15  1.0        15
# 16  1.0        16
# 17  1.0        17
# 18  1.0        18
# 19  1.0        19

# %% [markdown]
# multi collinearity removed

# %% [markdown]
# ## Regression model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import  GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import  Ridge
from sklearn.linear_model import  Lasso

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, Y, random_state=42, test_size=.33)

# %% [markdown]
# ## Find best random state

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
maxR2_score=0
maxRS=0
for i in range(1,500):
    X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=i, test_size=.33)
    lin_reg=LinearRegression()
    lin_reg.fit(X_train,Y_train)
    y_pred=lin_reg.predict(X_test)
    R2=r2_score(Y_test,y_pred)
    if R2>maxR2_score:
        maxR2_score=R2
        maxRS=i
print('Best R2 Score is', maxR2_score ,'on Random_state', maxRS)
# Out:
# Best R2 Score is 0.5216007266270611 on Random_state 106

# %%
from sklearn.model_selection import cross_val_score

# %%
lr=LinearRegression()
rf = RandomForestRegressor()
dtc = DecisionTreeRegressor()
XT = ExtraTreesRegressor()
BR = BaggingRegressor()
adb=AdaBoostRegressor()
gradb=GradientBoostingRegressor()
model = [lr,rf,XT,dtc,adb,gradb]

for m in model:
    m.fit(X_train,Y_train)
    m.score(X_train,Y_train)
    y_pred = m.predict(X_test)

    print('\033[1m'+' R2 Score :'+'\033[0m')
    print(r2_score(Y_test,y_pred)) 
    print('==============================================================================================================')
# Out:
#  R2 Score :
# 0.5000627484600051
# ...
#  R2 Score :
# 0.7520607727430991
# ...
#  R2 Score :
# 0.7783572540592343
# ...
#  R2 Score :
# 0.47499738301514927
# ...
#  R2 Score :
# 0.4494943465857023
# ...
#  R2 Score :
# 0.6170282819352265
# ...

# %%
# Cross Validation
model = [lr,rf,XT,dtc,adb,gradb]

for m in model:
    score = cross_val_score(m, X_scale, Y, cv =5)
    print('\n')
    print('\033[1m'+'Cross Validation Score :',m,":"+'\033[0m\n')
    print("Mean CV Score :",score.mean())
    print('==============================================================================================================')
# Out:
# Cross Validation Score : LinearRegression() :
#
# Mean CV Score : -0.622684752491325
# ...
#
#
# Cross Validation Score : RandomForestRegressor() :
#
# Mean CV Score : 0.6474392223707147
# ...
#
#
# Cross Validation Score : ExtraTreesRegressor() :
#
# Mean CV Score : 0.6777221903513914
# ...
#
#
# Cross Validation Score : DecisionTreeRegressor() :
#
# Mean CV Score : 0.5939999792583628
# ...
#
#
# Cross Validation Score : AdaBoostRegressor() :
#
# Mean CV Score : 0.4561828643326183
# ...
#
#
# Cross Validation Score : GradientBoostingRegressor() :
#
# Mean CV Score : 0.5972860013536094
# ...

# %% [markdown]
# ## Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter = {'n_estimators':[70],'max_depth': [25],
            'criterion':['mse','mae'],'min_samples_leaf': [5,10],
             'min_samples_split':[5,10],
             'max_features':["auto","sqrt"]}

# %%
GCV = GridSearchCV(RandomForestRegressor(),parameter,cv=3,n_jobs = -1,verbose=3)

# %%
GCV.fit(X_train,Y_train)
# Out:
# Fitting 3 folds for each of 16 candidates, totalling 48 fits

# %%
GCV.best_params_
# Out:
# {'criterion': 'mse',
#  'max_depth': 25,
#  'max_features': 'auto',
#  'min_samples_leaf': 5,
#  'min_samples_split': 5,
#  'n_estimators': 70}

# %% [markdown]
# ## Final model

# %%
Final = RandomForestRegressor(criterion='mse',max_depth= 25,max_features= 'auto',min_samples_leaf= 5,min_samples_split= 5,n_estimators= 70)
Final.fit(X_train,Y_train)
y_pred=Final.predict(X_test)
print('rmse:', np.sqrt(mean_squared_error(Y_test,y_pred)))
print('\n')
print('accuracy')
print(r2_score(Y_test,y_pred)) 
print('\n')
# Out:
# rmse: 12571.37063306618
#
#
# accuracy
# 0.5518473195658086

# %%
plt.figure(figsize=(20,9))
y_pred=Final.predict(X_test)
sns.scatterplot(Y_test.round(2), y_pred)
print(' True Values Vs Predicted Value plot :')
plt.xlabel('True Values' , fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.tight_layout()
# Out:
#  True Values Vs Predicted Value plot :

# %%
import joblib
joblib.dump(Final,'Price range.pkl')
# Out:
# ['Price range.pkl']
