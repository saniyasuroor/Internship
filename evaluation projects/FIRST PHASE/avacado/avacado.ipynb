# %% [raw]
# Avocado Project
# Project Description
# This data was downloaded from the Hass Avocado Board website in May of 2018 & compiled into a single CSV.
# The table below represents weekly 2018 retail scan data for National retail volume (units) and price. Retail scan data comes directly from retailers’ cash registers based on actual retail sales of Hass avocados.
# Starting in 2013, the table below reflects an expanded, multi-outlet retail data set. Multi-outlet reporting includes an aggregation of the following channels: grocery, mass, club, drug, dollar and military. The Average Price (of avocados) in the table reflects a per unit (per avocado) cost, even when multiple units (avocados) are sold in bags.
# The Product Lookup codes (PLU’s) in the table are only for Hass avocados. Other varieties of avocados (e.g. greenskins) are not included in this table.
# Some relevant columns in the dataset:
# Date - The date of the observation
# AveragePrice - the average price of a single avocado
# type - conventional or organic
# year - the year
# Region - the city or region of the observation
# Total Volume - Total number of avocados sold
# 4046 - Total number of avocados with PLU 4046 sold
# 4225 - Total number of avocados with PLU 4225 sold
# 4770 - Total number of avocados with PLU 4770 sold
#
# Inspiration /Label
# The dataset can be seen in two angles to find the region and find the average price .
# Task: One of Classification and other of Regression
# Do both tasks in the same .ipynb file and submit at single file.
#
# Dataset Link-
# https://github.com/dsrscientist/Data-Science-ML-Capstone-Projects/blob/master/avocado.csv.zip

# %% [markdown]
# # import header files

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns  
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # read dataset

# %%
df=pd.read_csv('Avacado.csv')

# %% [markdown]
# # statistical analysis

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# 4  2015  Albany

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df.dtypes
# Out:
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  object
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   4046          18249 non-null  float64
#  4   4225          18249 non-null  float64
#  5   4770          18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  object
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 1.8+ MB

# %%
df.shape
# Out:
# (18249, 13)

# %%
df.describe().T
# Out:
#                 count           mean           std      min       25%  \
# AveragePrice  18249.0       1.405978  4.026766e-01     0.44      1.10
# Total Volume  18249.0  850644.013009  3.453545e+06    84.56  10838.58
# 4046          18249.0  293008.424531  1.264989e+06     0.00    854.07
# 4225          18249.0  295154.568356  1.204120e+06     0.00   3008.78
# 4770          18249.0   22839.735993  1.074641e+05     0.00      0.00
# Total Bags    18249.0  239639.202060  9.862424e+05     0.00   5088.64
# Small Bags    18249.0  182194.686696  7.461785e+05     0.00   2849.42
# Large Bags    18249.0   54338.088145  2.439660e+05     0.00    127.47
# XLarge Bags   18249.0    3106.426507  1.769289e+04     0.00      0.00
# year          18249.0    2016.147899  9.399385e-01  2015.00   2015.00
#
#                     50%        75%          max
# AveragePrice       1.37       1.66         3.25
# Total Volume  107376.76  432962.29  62505646.52
# 4046            8645.30  111020.20  22743616.17
# 4225           29061.02  150206.86  20470572.61
# 4770             184.99    6243.42   2546439.11
# Total Bags     39743.83  110783.37  19373134.37
# Small Bags     26362.82   83337.67  13384586.80
# Large Bags      2647.71   22029.25   5719096.61
# XLarge Bags        0.00     132.50    551693.65
# year            2016.00    2017.00      2018.00

# %%
df['Year'],df['Month'],df['Day']= df['Date'].str.split('-').str
df.drop(columns=['Date','year'],inplace=True)
df
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags          type            region  \
# 0         8603.62       93.25          0.0  conventional            Albany
# 1         9408.07       97.49          0.0  conventional            Albany
# 2         8042.21      103.14          0.0  conventional            Albany
# 3         5677.40      133.76          0.0  conventional            Albany
# 4         5986.26      197.69          0.0  conventional            Albany
# ...           ...         ...          ...           ...               ...
# 18244    13066.82      431.85          0.0       organic  WestTexNewMexico
# 18245     8940.04      324.80          0.0       organic  WestTexNewMexico
# 18246     9351.80       42.31          0.0       organic  WestTexNewMexico
# 18247    10919.54       50.00          0.0       organic  WestTexNewMexico
# 18248    11988.14       26.01          0.0       organic  WestTexNewMexico
#
#        Year Month Day
# 0      2015    12  27
# 1      2015    12  20
# 2      2015    12  13
# 3      2015    12  06
# 4      2015    11  29
# ...     ...   ...  ..
# 18244  2018    02  04
# 18245  2018    01  28
# 18246  2018    01  21
# 18247  2018    01  14
# 18248  2018    01  07
#
# [18249 rows x 14 columns]

# %%
df['Year']=df['Year'].astype(int)
df['Month']=df['Month'].astype(int)
df['Date']=df['Day'].astype(int)
df.drop(columns=['Day'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AveragePrice  18249 non-null  float64
#  1   Total Volume  18249 non-null  float64
#  2   4046          18249 non-null  float64
#  3   4225          18249 non-null  float64
#  4   4770          18249 non-null  float64
#  5   Total Bags    18249 non-null  float64
#  6   Small Bags    18249 non-null  float64
#  7   Large Bags    18249 non-null  float64
#  8   XLarge Bags   18249 non-null  float64
#  9   type          18249 non-null  object
#  10  region        18249 non-null  object
#  11  Year          18249 non-null  int32
#  12  Month         18249 non-null  int32
#  13  Date          18249 non-null  int32
# dtypes: float64(9), int32(3), object(2)
# memory usage: 1.7+ MB

# %%
plt.figure(figsize=(20,8))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum()
# Out:
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# region          0
# Year            0
# Month           0
# Date            0
# dtype: int64

# %% [markdown]
# # univariant analysis

# %%
sns.set_palette('cool')
plt.figure(figsize=(50,40), facecolor='white')
plotnumber =1
for column in df:
    if plotnumber <=17:
        ax = plt.subplot(6,3,plotnumber)
        sns.histplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [raw]
# Most of cases Average price of Avacado varies between 1.1 and 1.6 USD/unit
# Avacado availability and price also vary over the year according to seasonal changes.Lets check the variation Avg price and sales volume over each month.
# This dataset contain data from 2015 to 2018
# Maximum sales entry belongs to year 2017 while very few sales entry comes from 2018.

# %% [markdown]
# # bivariant analysis

# %%
plt.figure(figsize=(18,24))
sns.barplot(df['region'],df['Year'])
plt.xticks(rotation=90)
plt.xlabel('region',fontsize =13)
plt.ylabel('Year',fontsize =13)
# Out:
# Text(0, 0.5, 'Year')

# %%
plt.figure(figsize=(40,18))
sns.barplot(df['AveragePrice'],df['region'])
plt.xlabel('AveragePrice',fontsize=30)
plt.ylabel('region',fontsize=30)
# Out:
# Text(0, 0.5, 'region')

# %%
plt.figure(figsize=(18,24))
sns.barplot(df['region'],df['Month'])
plt.xticks(rotation=90)
plt.xlabel('region',fontsize =13)
plt.ylabel('Month',fontsize =13)
# Out:
# Text(0, 0.5, 'Month')

# %%
plt.figure(figsize=(18,24))
sns.barplot(df['region'],df['Total Volume'])
plt.xticks(rotation=90)
plt.xlabel('region',fontsize =13)
plt.ylabel('Total Volume',fontsize =13)
# Out:
# Text(0, 0.5, 'Total Volume')

# %% [markdown]
# # multivariant analysis

# %%
feature = df[["Small Bags","Large Bags","XLarge Bags"]].groupby(df.region).sum()
feature.plot(kind='line', fontsize=10,figsize=(10,6))
plt.title("Type of bags sold vs Year")
plt.xlabel("Region")
plt.ylabel("Type of bags sold")
plt.show()

# %%
plt.figure(figsize=(30,30))
sns.scatterplot(df['region'],df['Total Bags'],hue=df['Year'])
plt.xticks(rotation=90)
plt.xlabel('region',fontsize =13)
plt.ylabel('Total Bags',fontsize =13)
# Out:
# Text(0, 0.5, 'Total Bags')

# %%
df.groupby(['region'])['Total Volume','AveragePrice'].agg([sum])
# Out:
#                      Total Volume AveragePrice
#                               sum          sum
# region
# Albany               1.606780e+07       527.63
# Atlanta              8.860512e+07       452.23
# BaltimoreWashington  1.347139e+08       518.57
# Boise                1.441319e+07       455.67
# Boston               9.727398e+07       517.44
# BuffaloRochester     2.296247e+07       512.69
# California           1.028982e+09       471.62
# Charlotte            3.555554e+07       542.84
# Chicago              1.337023e+08       526.19
# CincinnatiDayton     4.452201e+07       408.71
# Columbus             2.999336e+07       423.44
# DallasFtWorth        2.084193e+08       366.93
# Denver               1.389025e+08       411.88
# Detroit              6.342242e+07       431.32
# GrandRapids          3.021174e+07       508.69
# GreatLakes           5.896425e+08       452.43
# HarrisburgScranton   4.180886e+07       511.49
# HartfordSpringfield  5.067054e+07       614.70
# Houston              2.031679e+08       354.20
# Indianapolis         3.026339e+07       444.13
# Jacksonville         2.879000e+07       510.70
# LasVegas             5.437691e+07       466.75
# LosAngeles           5.078965e+08       411.01
# Louisville           1.609700e+07       434.90
# MiamiFtLauderdale    9.767322e+07       482.83
# Midsouth             5.083494e+08       474.81
# Nashville            3.561209e+07       409.69
# NewOrleansMobile     4.569514e+07       441.02
# NewYork              2.407341e+08       583.92
# Northeast            7.132809e+08       541.45
# NorthernNewEngland   7.153289e+07       499.36
# Orlando              5.866070e+07       509.10
# Philadelphia         7.183880e+07       551.66
# PhoenixTucson        1.956433e+08       413.86
# Pittsburgh           1.880635e+07       461.14
# Plains               3.111885e+08       485.54
# Portland             1.105522e+08       445.39
# RaleighGreensboro    4.820273e+07       525.63
# RichmondNorfolk      4.223085e+07       436.47
# Roanoke              2.504201e+07       421.80
# Sacramento           7.516375e+07       548.09
# SanDiego             8.979192e+07       472.58
# SanFrancisco         1.358302e+08       609.82
# Seattle              1.092142e+08       487.59
# SouthCarolina        6.075377e+07       474.31
# SouthCentral         1.011280e+09       372.22
# Southeast            6.152384e+08       472.53
# Spokane              1.556528e+07       488.61
# StLouis              3.207283e+07       483.55
# Syracuse             1.094267e+07       513.87
# Tampa                6.600454e+07       476.19
# TotalUS              5.864740e+09       445.83
# West                 1.086779e+09       430.01
# WestTexNewMexico     1.445218e+08       422.67

# %%
df.groupby(['region'])['Total Volume','Total Bags','Small Bags','Large Bags','XLarge Bags'].agg([np.mean])
# Out:
#                      Total Volume     Total Bags     Small Bags  \
#                              mean           mean           mean
# region
# Albany               4.753787e+04    7929.747367    6647.765473
# Atlanta              2.621453e+05   84498.560888   51605.727337
# BaltimoreWashington  3.985619e+05  104456.053462  100939.683195
# Boise                4.264257e+04   15974.592456   13840.037249
# Boston               2.877929e+05   63596.085207   58906.590355
# BuffaloRochester     6.793630e+04   34351.336183   30379.975710
# California           2.459960e+06  550340.538621  506126.355621
# Charlotte            1.051939e+05   34609.297071   31490.685118
# Chicago              3.955690e+05   49897.634970   43771.162929
# CincinnatiDayton     1.317219e+05   61828.161065   16751.165444
# Columbus             8.873776e+04   29634.281746   23878.084941
# DallasFtWorth        6.166251e+05  137484.475000  120774.367101
# Denver               4.109542e+05  174429.014793   55513.624763
# Detroit              1.876403e+05   71775.341272   58991.335473
# GrandRapids          8.938383e+04   27127.496893   22288.393669
# GreatLakes           1.263357e+06  410377.173493  281177.567353
# HarrisburgScranton   1.236948e+05   40027.379083   37789.562781
# HartfordSpringfield  1.499128e+05   33529.623166   31889.232781
# Houston              6.010884e+05  148565.278166   96228.305740
# Indianapolis         8.953666e+04   35446.183491   19559.359822
# Jacksonville         8.517753e+04   28751.856479   12839.605237
# LasVegas             1.608784e+05   53411.223107   26561.015858
# LosAngeles           1.459657e+06  474436.212810  437936.584441
# Louisville           4.762427e+04   19631.031893    8326.157396
# MiamiFtLauderdale    2.889740e+05   69575.274438   33195.188373
# Midsouth             1.476622e+06  457528.903453  393091.874234
# Nashville            1.053612e+05   38364.397663   29712.387101
# NewOrleansMobile     1.351927e+05   42215.800325   35087.439586
# NewYork              7.122311e+05  201166.144260  172786.042899
# Northeast            1.976197e+06  556754.508492  490773.668554
# NorthernNewEngland   2.116358e+05   41139.134320   33363.818047
# Orlando              1.735524e+05   49886.510888   26413.842604
# Philadelphia         2.125408e+05   70636.781805   63363.976006
# PhoenixTucson        5.788264e+05  115113.125148   65895.350030
# Pittsburgh           5.564008e+04   21436.279379   16000.532959
# Plains               9.206761e+05  230317.174408  203433.798639
# Portland             3.270775e+05  146462.601982  122806.571657
# RaleighGreensboro    1.426116e+05   46380.702633   44498.471331
# RichmondNorfolk      1.249433e+05   37006.594024   34486.695296
# Roanoke              7.408879e+04   28375.703254   25018.755089
# Sacramento           2.223779e+05   26574.757751   25730.298728
# SanDiego             2.656566e+05   69061.149467   59987.543817
# SanFrancisco         4.018645e+05   44055.991036   42906.364320
# Seattle              3.231189e+05  149974.552456  125583.256302
# SouthCarolina        1.797449e+05   53707.614734   39684.459053
# SouthCentral         2.420087e+06  551607.024452  441547.084521
# Southeast            1.553508e+06  451455.330098  279133.494072
# Spokane              4.605111e+04   18504.070621   15882.578462
# StLouis              9.489004e+04   43597.724763   35301.348876
# Syracuse             3.237476e+04   12403.631509   10785.950917
# Tampa                1.952797e+05   57682.520444   31384.835325
# TotalUS              9.675657e+05  505369.853491  358176.323550
# West                 2.047382e+06  545837.754180  359004.126523
# WestTexNewMexico     4.314085e+05  105362.732925   59497.779970
#
#                         Large Bags   XLarge Bags
#                               mean          mean
# region
# Albany                 1153.496213    128.488639
# Atlanta               32070.044556    822.786036
# BaltimoreWashington    2903.984586    612.382722
# Boise                  2103.634083     30.915207
# Boston                 4438.364704    251.124231
# BuffaloRochester       3729.050000    242.313432
# California            35753.156966   8461.026034
# Charlotte              2912.684172    205.927781
# Chicago                5005.546864   1120.925178
# CincinnatiDayton      44296.434290    780.564290
# Columbus               5103.195266    653.004497
# DallasFtWorth         15431.128373   1278.973609
# Denver               118760.122929    155.270059
# Detroit                7905.232308   4878.770533
# GrandRapids            2357.397988   2481.702278
# GreatLakes           121026.895662   8172.714154
# HarrisburgScranton     1780.372041    457.450178
# HartfordSpringfield    1410.793580    229.590888
# Houston               51372.082633    964.889793
# Indianapolis          15048.095976    838.727692
# Jacksonville          15600.603994    311.644290
# LasVegas              26802.706302     47.497988
# LosAngeles            25371.397523  11128.233867
# Louisville            10985.575740    319.298757
# MiamiFtLauderdale     35475.769527    904.313580
# Midsouth              60993.089700   3443.936517
# Nashville              8322.172811    329.840710
# NewOrleansMobile       5611.536183   1516.830473
# NewYork               27316.560888   1063.543432
# Northeast             62801.969662   3178.879508
# NorthernNewEngland     7447.945621    327.367692
# Orlando               22752.999556    719.665769
# Philadelphia           6958.744497    314.058343
# PhoenixTucson         48759.469260    458.308817
# Pittsburgh             5265.376538    170.369882
# Plains                23590.661893   3292.713876
# Portland              23425.222367    230.805000
# RaleighGreensboro      1601.023905    281.207396
# RichmondNorfolk        2153.671361    366.224408
# Roanoke                3121.787367    235.157840
# Sacramento              226.967574    617.488491
# SanDiego               8644.448935    429.156716
# SanFrancisco            523.488876    626.137840
# Seattle               24189.194260    202.101893
# SouthCarolina         13352.828373    670.327308
# SouthCentral         106313.541096   3746.398836
# Southeast            168283.610423   4038.215831
# Spokane                2600.241509     21.250651
# StLouis                7631.293373    665.082515
# Syracuse               1494.127515    123.556036
# Tampa                 25601.887101    695.795059
# TotalUS              147170.631775     22.880414
# West                 185798.268242   1035.359414
# WestTexNewMexico      44929.096090    935.853881

# %% [raw]
# Maximum sales Volume is in South Central While Minimum Sales Volume is in Syracuse.
# Maximum Average Price is in SanFrancisco and Minimum Average Sale price is in Houston.

# %% [markdown]
# # outliners dectection and removal

# %%
sns.set_palette('flare')
for col in df:
    plt.figure(figsize=(18,4))
    sns.boxplot(df[col])
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 2>()
#       2 for col in df:
#       3     plt.figure(figsize=(18,4))
# ----> 4     sns.boxplot(df[col])
#       5     plt.show()
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:2243, in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2231 @_deprecate_positional_args
#    2232 def boxplot(
#    2233     *,
#    (...)
#    2240     **kwargs
#    2241 ):
# -> 2243     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2244                           orient, color, palette, saturation,
#    2245                           width, dodge, fliersize, linewidth)
#    2247     if ax is None:
#    2248         ax = plt.gca()
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:406, in _BoxPlotter.__init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     402 def __init__(self, x, y, hue, data, order, hue_order,
#     403              orient, color, palette, saturation,
#     404              width, dodge, fliersize, linewidth):
# --> 406     self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     407     self.establish_colors(color, palette, saturation)
#     409     self.dodge = dodge
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:156, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     153         raise ValueError(err)
#     155 # Figure out the plotting orientation
# --> 156 orient = infer_orient(
#     157     x, y, orient, require_numeric=self.require_numeric
#     158 )
#     160 # Option 2a:
#     161 # We are plotting a single set of data
#     162 # ------------------------------------
#     163 if x is None or y is None:
#     164
#     165     # Determine where the data are
#
# File ~\anaconda3\lib\site-packages\seaborn\_core.py:1328, in infer_orient(x, y, orient, require_numeric)
#    1326         warnings.warn(single_var_warning.format("Vertical", "x"))
#    1327     if require_numeric and x_type != "numeric":
# -> 1328         raise TypeError(nonnumeric_dv_error.format("Horizontal", "x"))
#    1329     return "h"
#    1331 elif str(orient).startswith("v"):
#
# TypeError: Horizontal orientation requires numeric `x` variable.

# %% [markdown]
# # encoding categorical data

# %%
from sklearn.preprocessing import LabelEncoder
e = LabelEncoder()
df['region']=e.fit_transform(df['region'])
df['type']=e.fit_transform(df['type'])
df.head()
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags  type  region  Year  Month  Date
# 0     8603.62       93.25          0.0     0       0  2015     12    27
# 1     9408.07       97.49          0.0     0       0  2015     12    20
# 2     8042.21      103.14          0.0     0       0  2015     12    13
# 3     5677.40      133.76          0.0     0       0  2015     12     6
# 4     5986.26      197.69          0.0     0       0  2015     11    29

# %%
from scipy.stats import zscore
z = np.abs(zscore(df))
threshold = 3
df1 = df[(z<3).all(axis = 1)]

# %%
df1.shape
# Out:
# (17651, 14)

# %%
data_loss = (18249-17651)/18249*100
data_loss
# Out:
# 3.276891884486821

# %%
df=df1.copy()

# %% [markdown]
# # skewness dectection and removal

# %%
df.skew()
# Out:
# AveragePrice    0.377432
# Total Volume    3.767138
# 4046            4.909848
# 4225            4.455745
# 4770            5.117170
# Total Bags      4.066771
# Small Bags      4.222706
# Large Bags      5.053434
# XLarge Bags     6.135607
# type           -0.037741
# region          0.012798
# Year            0.229976
# Month           0.107408
# Date            0.011778
# dtype: float64

# %%
plt.figure(figsize=(20,30))
for i,column in enumerate(df.columns):
    plt.subplot(10,4,i+1)
    sns.distplot(df[column])

# %% [raw]
# mostly right skewed

# %%
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')

# %%
Features = ['Total Volume', '4046', '4225', '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags']
df[Features] = scaler.fit_transform(df[Features].values)

# %%
df.skew()
# Out:
# AveragePrice    0.377432
# Total Volume   -0.008642
# 4046           -0.039282
# 4225           -0.044675
# 4770            0.024168
# Total Bags     -0.022204
# Small Bags     -0.024405
# Large Bags     -0.110913
# XLarge Bags     0.853758
# type           -0.037741
# region          0.012798
# Year            0.229976
# Month           0.107408
# Date            0.011778
# dtype: float64

# %% [raw]
# 4046,4225,4770 dont provide information in analysis lets skip it

# %% [markdown]
# # correlation dectection and removal

# %%
df.corr()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.580126 -0.554612 -0.453664 -0.493607
# Total Volume     -0.580126      1.000000  0.889248  0.924664  0.818545
# 4046             -0.554612      0.889248  1.000000  0.764456  0.737191
# 4225             -0.453664      0.924664  0.764456  1.000000  0.797186
# 4770             -0.493607      0.818545  0.737191  0.797186  1.000000
# Total Bags       -0.564105      0.941082  0.800798  0.820596  0.761056
# Small Bags       -0.489430      0.905795  0.779462  0.786441  0.753593
# Large Bags       -0.484384      0.682569  0.603598  0.616089  0.547691
# XLarge Bags      -0.393086      0.629882  0.574335  0.584748  0.616930
# type              0.613150     -0.799821 -0.725000 -0.747349 -0.780137
# region           -0.003242      0.068983  0.162069  0.033926  0.041295
# Year              0.091704      0.080706  0.001350 -0.001524 -0.049934
# Month             0.149502     -0.021861 -0.021731 -0.021967 -0.013533
# Date              0.026819     -0.006430 -0.005191 -0.006289  0.001251
#
#               Total Bags  Small Bags  Large Bags  XLarge Bags      type  \
# AveragePrice   -0.564105   -0.489430   -0.484384    -0.393086  0.613150
# Total Volume    0.941082    0.905795    0.682569     0.629882 -0.799821
# 4046            0.800798    0.779462    0.603598     0.574335 -0.725000
# 4225            0.820596    0.786441    0.616089     0.584748 -0.747349
# 4770            0.761056    0.753593    0.547691     0.616930 -0.780137
# Total Bags      1.000000    0.949975    0.729681     0.613741 -0.724752
# Small Bags      0.949975    1.000000    0.566610     0.604123 -0.719063
# Large Bags      0.729681    0.566610    1.000000     0.451305 -0.498894
# XLarge Bags     0.613741    0.604123    0.451305     1.000000 -0.665473
# type           -0.724752   -0.719063   -0.498894    -0.665473  1.000000
# region          0.071460    0.057312    0.089954    -0.019668  0.018409
# Year            0.214666    0.190267    0.191742     0.161582  0.003867
# Month          -0.009209   -0.004761   -0.014694     0.020729 -0.009499
# Date           -0.003164   -0.000222   -0.000130     0.010752 -0.002287
#
#                 region      Year     Month      Date
# AveragePrice -0.003242  0.091704  0.149502  0.026819
# Total Volume  0.068983  0.080706 -0.021861 -0.006430
# 4046          0.162069  0.001350 -0.021731 -0.005191
# 4225          0.033926 -0.001524 -0.021967 -0.006289
# 4770          0.041295 -0.049934 -0.013533  0.001251
# Total Bags    0.071460  0.214666 -0.009209 -0.003164
# Small Bags    0.057312  0.190267 -0.004761 -0.000222
# Large Bags    0.089954  0.191742 -0.014694 -0.000130
# XLarge Bags  -0.019668  0.161582  0.020729  0.010752
# type          0.018409  0.003867 -0.009499 -0.002287
# region        1.000000 -0.004417  0.000119 -0.000046
# Year         -0.004417  1.000000 -0.175287  0.004700
# Month         0.000119 -0.175287  1.000000  0.011917
# Date         -0.000046  0.004700  0.011917  1.000000

# %%
plt.figure(figsize=(20,8))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (18,6))
df.corr()['region'].drop(['region']).plot(kind='bar',color = 'c')
plt.xlabel('Features',fontsize=15)
plt.ylabel('region',fontsize=15)
plt.show()

# %% [raw]
# we have high correlation we can solve it by removing some coloums that aare not involved in analysing

# %%
df.drop(columns=['4046','4225','4770','Total Bags','Year'],axis=1, inplace=True)

# %%
df1=df.copy()
df1.head()
# Out:
#    AveragePrice  Total Volume  Small Bags  Large Bags  XLarge Bags  type  \
# 0          1.33     -0.075324   -0.347421   -0.781153    -0.677919     0
# 1          1.35     -0.147497   -0.311322   -0.771198    -0.677919     0
# 2          0.93      0.205556   -0.374453   -0.758523    -0.677919     0
# 3          1.08      0.019655   -0.510991   -0.699123    -0.677919     0
# 4          1.28     -0.180674   -0.490534   -0.607027    -0.677919     0
#
#    region  Month  Date
# 0       0     12    27
# 1       0     12    20
# 2       0     12    13
# 3       0     12     6
# 4       0     11    29

# %%
df2=df.copy()
df2.head()
# Out:
#    AveragePrice  Total Volume  Small Bags  Large Bags  XLarge Bags  type  \
# 0          1.33     -0.075324   -0.347421   -0.781153    -0.677919     0
# 1          1.35     -0.147497   -0.311322   -0.771198    -0.677919     0
# 2          0.93      0.205556   -0.374453   -0.758523    -0.677919     0
# 3          1.08      0.019655   -0.510991   -0.699123    -0.677919     0
# 4          1.28     -0.180674   -0.490534   -0.607027    -0.677919     0
#
#    region  Month  Date
# 0       0     12    27
# 1       0     12    20
# 2       0     12    13
# 3       0     12     6
# 4       0     11    29

# %%
x = df1.drop('region', axis=1)
y = df1['region']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x.head()
# Out:
#    AveragePrice  Total Volume      4046      4225      4770  Total Bags  \
# 0     -0.195352     -0.392009 -0.349452 -0.278497 -0.322219   -0.429348
# 1     -0.143510     -0.401251 -0.350276 -0.303093 -0.321924   -0.426481
# 2     -1.232207     -0.338702 -0.350002 -0.141449 -0.319832   -0.431303
# 3     -0.843387     -0.377438 -0.349235 -0.234593 -0.321511   -0.439577
# 4     -0.324959     -0.405040 -0.349668 -0.305098 -0.321418   -0.438256
#
#    Small Bags  Large Bags  XLarge Bags      type      Year     Month      Date
# 0   -0.400967   -0.379832    -0.259027 -1.019047 -1.210013  1.644612  1.289309
# 1   -0.397462   -0.379774    -0.259027 -1.019047 -1.210013  1.644612  0.491652
# 2   -0.403413   -0.379696    -0.259027 -1.019047 -1.210013  1.644612 -0.306004
# 3   -0.413717   -0.379277    -0.259027 -1.019047 -1.210013  1.644612 -1.103660
# 4   -0.412371   -0.378402    -0.259027 -1.019047 -1.210013  1.362113  1.517211

# %% [markdown]
# # multicolinearity dectection and removal

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["Features"]=x.columns
vif["VIF Value"]=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif
# Out:
#         Features     VIF Value
# 0   AveragePrice  1.794534e+00
# 1   Total Volume  4.128047e+08
# 2           4046  7.777217e+07
# 3           4225  6.410960e+07
# 4           4770  4.787466e+05
# 5     Total Bags  1.924615e+13
# 6     Small Bags  1.275807e+13
# 7     Large Bags  1.290985e+12
# 8    XLarge Bags  6.647370e+09
# 9           type  1.844426e+00
# 10          Year  1.160672e+00
# 11         Month  1.095433e+00
# 12          Date  1.002126e+00

# %% [raw]
# no multicollinearity

# %% [markdown]
# # building classification model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import cross_val_score

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.25, random_state =i)
    DTC = DecisionTreeClassifier()
    DTC.fit(x_train, y_train)
    pred = DTC.predict(x_test)
    acc=accuracy_score(y_test, pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Best accuracy is ",maxAccu," on Random_state ",maxRS)
# Out:
# Best accuracy is  0.8060276455925675  on Random_state  117

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=186)

# %%
model=[
        LogisticRegression(),
        SVC(),
        GaussianNB(),
        DecisionTreeClassifier(),
        KNeighborsClassifier(n_neighbors = 22),
        RandomForestClassifier(),
        GradientBoostingClassifier(),
        BaggingClassifier()]

for m in model:
    m.fit(x_train,y_train)
    y_pred=m.predict(x_test)
    print(accuracy_score(y_test, y_pred))
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test,y_pred))
    print('cv:',cross_val_score(m,x,y,cv=5).mean())
    print('============================================================================================================')
# Out:
# 0.2756797583081571
# [[18  0  0 ...  0  0  0]
#  [ 0  9  0 ...  0  0  7]
#  [ 0  0 28 ...  0  0  1]
#  ...
#  [ 0  0  0 ... 54  0  0]
#  [ 0  0  0 ...  2 57  0]
#  [ 0  1  0 ...  0  0  3]]
#               precision    recall  f1-score   support
#
#            0       0.13      0.19      0.15        93
#            1       0.13      0.08      0.10       117
#            2       0.39      0.32      0.35        87
#            3       0.28      0.25      0.26        92
#            4       0.13      0.11      0.12       100
#            5       0.19      0.13      0.16       112
#            6       0.65      0.70      0.67        84
#            7       0.20      0.18      0.19       101
#            8       0.49      0.51      0.50       104
#            9       0.25      0.57      0.35        86
#           10       0.24      0.12      0.16       103
#           11       0.22      0.41      0.29        94
#           12       0.27      0.49      0.35       101
#           13       0.18      0.25      0.21        93
#           14       0.14      0.25      0.18        97
#           15       0.33      0.19      0.24        84
#           16       0.10      0.09      0.09       112
#           17       0.27      0.44      0.33        94
#           18       0.22      0.24      0.23        95
#           19       0.21      0.38      0.27        97
#           20       0.12      0.09      0.11       108
#           21       0.13      0.16      0.14        91
#           22       0.37      0.40      0.38       112
#           23       0.41      0.74      0.52       103
#           24       0.00      0.00      0.00       106
#           25       0.39      0.33      0.36        99
#           26       0.11      0.09      0.10       104
#           27       0.14      0.20      0.17       102
#           28       0.45      0.52      0.48        98
#           29       0.57      0.76      0.65        94
#           30       0.30      0.46      0.37       105
#           31       0.12      0.08      0.10        97
#           32       0.33      0.32      0.33       113
#           33       0.00      0.00      0.00       106
#           34       0.20      0.32      0.25        93
#           35       0.34      0.31      0.32       111
#           36       0.20      0.15      0.17        99
#           37       0.25      0.02      0.03       123
#           38       0.12      0.05      0.07       113
#           39       0.12      0.07      0.08        92
#           40       0.36      0.55      0.43        93
#           41       0.15      0.09      0.11        87
#           42       0.47      0.60      0.53        87
#           43       0.25      0.17      0.20        98
#           44       0.14      0.12      0.13       104
#           45       0.43      0.54      0.48        85
#           46       0.18      0.17      0.17        90
#           47       0.37      0.25      0.30       106
#           48       0.00      0.00      0.00       104
#           49       0.26      0.40      0.32       106
#           50       0.09      0.03      0.05        91
#           51       0.96      0.98      0.97        55
#           52       0.53      0.75      0.62        76
#           53       0.05      0.03      0.04        99
#
#     accuracy                           0.28      5296
#    macro avg       0.26      0.29      0.26      5296
# weighted avg       0.25      0.28      0.25      5296
#
# cv: 0.19488881561371035
# ============================================================================================================
# 0.4137084592145015
# [[75  0  0 ...  0  0  0]
#  [ 0 26  0 ...  0  0  9]
#  [ 0  0 40 ...  0  0  1]
#  ...
#  [ 0  0  0 ... 54  1  0]
#  [ 0  0  0 ...  1 44  0]
#  [ 0  4  2 ...  0  0 22]]
#               precision    recall  f1-score   support
#
#            0       0.34      0.81      0.48        93
#            1       0.29      0.22      0.25       117
#            2       0.48      0.46      0.47        87
#            3       0.40      0.32      0.35        92
#            4       0.60      0.39      0.47       100
#            5       0.51      0.33      0.40       112
#            6       0.76      0.68      0.72        84
#            7       0.25      0.33      0.28       101
#            8       0.72      0.63      0.67       104
#            9       0.35      0.74      0.48        86
#           10       0.28      0.26      0.27       103
#           11       0.38      0.56      0.45        94
#           12       0.69      0.41      0.51       101
#           13       0.23      0.33      0.27        93
#           14       0.40      0.51      0.45        97
#           15       0.48      0.40      0.44        84
#           16       0.19      0.12      0.15       112
#           17       0.31      0.47      0.37        94
#           18       0.41      0.43      0.42        95
#           19       0.28      0.44      0.34        97
#           20       0.28      0.19      0.23       108
#           21       0.20      0.23      0.21        91
#           22       0.70      0.55      0.62       112
#           23       0.46      0.54      0.50       103
#           24       0.35      0.28      0.31       106
#           25       0.46      0.53      0.49        99
#           26       0.24      0.20      0.22       104
#           27       0.29      0.19      0.23       102
#           28       0.64      0.64      0.64        98
#           29       0.68      0.80      0.73        94
#           30       0.38      0.55      0.45       105
#           31       0.09      0.06      0.07        97
#           32       0.54      0.49      0.51       113
#           33       0.59      0.39      0.47       106
#           34       0.26      0.41      0.32        93
#           35       0.53      0.68      0.60       111
#           36       0.46      0.35      0.40        99
#           37       0.35      0.27      0.31       123
#           38       0.18      0.12      0.15       113
#           39       0.20      0.36      0.26        92
#           40       0.48      0.43      0.45        93
#           41       0.31      0.09      0.14        87
#           42       0.76      0.77      0.77        87
#           43       0.63      0.57      0.60        98
#           44       0.21      0.31      0.25       104
#           45       0.56      0.82      0.66        85
#           46       0.55      0.46      0.50        90
#           47       0.54      0.42      0.48       106
#           48       0.42      0.11      0.17       104
#           49       0.53      0.33      0.41       106
#           50       0.25      0.15      0.19        91
#           51       0.98      0.98      0.98        55
#           52       0.76      0.58      0.66        76
#           53       0.22      0.22      0.22        99
#
#     accuracy                           0.41      5296
#    macro avg       0.43      0.42      0.42      5296
# weighted avg       0.43      0.41      0.41      5296
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [37], in <cell line: 11>()
#      15 print(confusion_matrix(y_test, y_pred))
#      16 print(classification_report(y_test,y_pred))
# ---> 17 print('cv:',cross_val_score(m,x,y,cv=5).mean())
#      18 print('============================================================================================================')
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:509, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     506 # To ensure multimetric format is not supported
#     507 scorer = check_scoring(estimator, scoring=scoring)
# --> 509 cv_results = cross_validate(
#     510     estimator=estimator,
#     511     X=X,
#     512     y=y,
#     513     groups=groups,
#     514     scoring={"score": scorer},
#     515     cv=cv,
#     516     n_jobs=n_jobs,
#     517     verbose=verbose,
#     518     fit_params=fit_params,
#     519     pre_dispatch=pre_dispatch,
#     520     error_score=error_score,
#     521 )
#     522 return cv_results["test_score"]
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:267, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     264 # We clone the estimator to make sure that all the folds are
#     265 # independent, and that it is pickle-able.
#     266 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 267 results = parallel(
#     268     delayed(_fit_and_score)(
#     269         clone(estimator),
#     270         X,
#     271         y,
#     272         scorers,
#     273         train,
#     274         test,
#     275         verbose,
#     276         None,
#     277         fit_params,
#     278         return_train_score=return_train_score,
#     279         return_times=True,
#     280         return_estimator=return_estimator,
#     281         error_score=error_score,
#     282     )
#     283     for train, test in cv.split(X, y, groups)
#     284 )
#     286 _warn_about_fit_failures(results, error_score)
#     288 # For callabe scoring, the return type is only know after calling. If the
#     289 # return type is a dictionary, the error scores can now be inserted with
#     290 # the correct key.
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:1046, in Parallel.__call__(self, iterable)
#    1043 if self.dispatch_one_batch(iterator):
#    1044     self._iterating = self._original_iterator is not None
# -> 1046 while self.dispatch_one_batch(iterator):
#    1047     pass
#    1049 if pre_dispatch == "all" or n_jobs == 1:
#    1050     # The iterable was consumed all at once by the above for loop.
#    1051     # No need to wait for async callbacks to trigger to
#    1052     # consumption.
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:861, in Parallel.dispatch_one_batch(self, iterator)
#     859     return False
#     860 else:
# --> 861     self._dispatch(tasks)
#     862     return True
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:779, in Parallel._dispatch(self, batch)
#     777 with self._lock:
#     778     job_idx = len(self._jobs)
# --> 779     job = self._backend.apply_async(batch, callback=cb)
#     780     # A job can complete so quickly than its callback is
#     781     # called before we get here, causing self._jobs to
#     782     # grow. To ensure correct results ordering, .insert is
#     783     # used (rather than .append) in the following line
#     784     self._jobs.insert(job_idx, job)
#
# File ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:262, in BatchedCalls.__call__(self)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:262, in <listcomp>(.0)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\fixes.py:216, in _FuncWrapper.__call__(self, *args, **kwargs)
#     214 def __call__(self, *args, **kwargs):
#     215     with config_context(**self.config):
# --> 216         return self.function(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:702, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     699 result["fit_error"] = None
#     701 fit_time = time.time() - start_time
# --> 702 test_scores = _score(estimator, X_test, y_test, scorer, error_score)
#     703 score_time = time.time() - start_time - fit_time
#     704 if return_train_score:
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:761, in _score(estimator, X_test, y_test, scorer, error_score)
#     759         scores = scorer(estimator, X_test)
#     760     else:
# --> 761         scores = scorer(estimator, X_test, y_test)
#     762 except Exception:
#     763     if error_score == "raise":
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py:105, in _MultimetricScorer.__call__(self, estimator, *args, **kwargs)
#     103         score = scorer._score(cached_call, estimator, *args, **kwargs)
#     104     else:
# --> 105         score = scorer(estimator, *args, **kwargs)
#     106     scores[name] = score
#     107 return scores
#
# File ~\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py:418, in _passthrough_scorer(estimator, *args, **kwargs)
#     416 def _passthrough_scorer(estimator, *args, **kwargs):
#     417     """Function that wraps estimator.score"""
# --> 418     return estimator.score(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:651, in ClassifierMixin.score(self, X, y, sample_weight)
#     626 """
#     627 Return the mean accuracy on the given test data and labels.
#     628
#    (...)
#     647     Mean accuracy of ``self.predict(X)`` wrt. `y`.
#     648 """
#     649 from .metrics import accuracy_score
# --> 651 return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#
# File ~\anaconda3\lib\site-packages\sklearn\svm\_base.py:791, in BaseSVC.predict(self, X)
#     789     y = np.argmax(self.decision_function(X), axis=1)
#     790 else:
# --> 791     y = super().predict(X)
#     792 return self.classes_.take(np.asarray(y, dtype=np.intp))
#
# File ~\anaconda3\lib\site-packages\sklearn\svm\_base.py:416, in BaseLibSVM.predict(self, X)
#     414 X = self._validate_for_predict(X)
#     415 predict = self._sparse_predict if self._sparse else self._dense_predict
# --> 416 return predict(X)
#
# File ~\anaconda3\lib\site-packages\sklearn\svm\_base.py:435, in BaseLibSVM._dense_predict(self, X)
#     427         raise ValueError(
#     428             "X.shape[1] = %d should be equal to %d, "
#     429             "the number of samples at training time"
#     430             % (X.shape[1], self.shape_fit_[0])
#     431         )
#     433 svm_type = LIBSVM_IMPL.index(self._impl)
# --> 435 return libsvm.predict(
#     436     X,
#     437     self.support_,
#     438     self.support_vectors_,
#     439     self._n_support,
#     440     self._dual_coef_,
#     441     self._intercept_,
#     442     self._probA,
#     443     self._probB,
#     444     svm_type=svm_type,
#     445     kernel=kernel,
#     446     degree=self.degree,
#     447     coef0=self.coef0,
#     448     gamma=self._gamma,
#     449     cache_size=self.cache_size,
#     450 )
#
# KeyboardInterrupt:

# %%
LR = LogisticRegression()
LR.fit(x_train,y_train)

predLR = LR.predict(x_test)

print(accuracy_score(y_test, predLR))
print(confusion_matrix(y_test, predLR))
print(classification_report(y_test,predLR))
print('cv:',cross_val_score(LR,x,y,cv=5).mean())
# Out:
# 0.26189577039274925
# [[16  0  0 ...  0  0  0]
#  [ 0  4  0 ...  0  0  3]
#  [ 0  2 24 ...  0  0  1]
#  ...
#  [ 0  0  0 ... 47  1  0]
#  [ 0  0  0 ...  1 52  0]
#  [ 0  1  0 ...  0  0  1]]
#               precision    recall  f1-score   support
#
#            0       0.13      0.15      0.14       104
#            1       0.04      0.04      0.04        96
#            2       0.32      0.24      0.28        98
#            3       0.38      0.21      0.27       109
#            4       0.13      0.06      0.08       114
#            5       0.16      0.18      0.17       111
#            6       0.48      0.65      0.55        77
#            7       0.18      0.05      0.08       111
#            8       0.44      0.42      0.43        99
#            9       0.26      0.45      0.33       104
#           10       0.21      0.14      0.17        97
#           11       0.21      0.42      0.28        85
#           12       0.26      0.51      0.35        87
#           13       0.25      0.24      0.24       105
#           14       0.15      0.27      0.19        93
#           15       0.30      0.15      0.20        79
#           16       0.12      0.11      0.11        99
#           17       0.28      0.38      0.32       104
#           18       0.15      0.18      0.16        98
#           19       0.24      0.38      0.29       100
#           20       0.14      0.09      0.11       107
#           21       0.12      0.10      0.11       108
#           22       0.39      0.39      0.39       119
#           23       0.30      0.64      0.41        86
#           24       0.00      0.00      0.00        95
#           25       0.34      0.40      0.37        95
#           26       0.11      0.11      0.11        89
#           27       0.18      0.22      0.20       104
#           28       0.38      0.50      0.43       100
#           29       0.56      0.70      0.62       107
#           30       0.33      0.57      0.42       103
#           31       0.18      0.04      0.07       116
#           32       0.25      0.28      0.26       102
#           33       0.25      0.05      0.09        91
#           34       0.16      0.20      0.18        90
#           35       0.35      0.28      0.31       120
#           36       0.07      0.05      0.06       106
#           37       0.07      0.03      0.04       102
#           38       0.09      0.07      0.08        98
#           39       0.03      0.01      0.01       102
#           40       0.41      0.56      0.47        96
#           41       0.26      0.12      0.17        88
#           42       0.45      0.53      0.49        95
#           43       0.19      0.23      0.21        91
#           44       0.14      0.13      0.14       104
#           45       0.46      0.52      0.49       105
#           46       0.29      0.22      0.25       104
#           47       0.23      0.23      0.23        92
#           48       0.04      0.01      0.02        83
#           49       0.25      0.45      0.32        96
#           50       0.10      0.08      0.09        98
#           51       0.94      0.90      0.92        52
#           52       0.50      0.67      0.57        78
#           53       0.03      0.01      0.01       104
#
#     accuracy                           0.26      5296
#    macro avg       0.25      0.27      0.25      5296
# weighted avg       0.24      0.26      0.24      5296
#
# cv: 0.19539903549540574

# %%
knn = KNN()
knn.fit(x_train,y_train)

predknn = knn.predict(x_test)

print(accuracy_score(y_test, predknn))
print(confusion_matrix(y_test, predknn))
print(classification_report(y_test,predknn))
print('cv:',cross_val_score(knn,x,y,cv=5).mean())
# Out:
# 0.24169184290030213
# [[64  0  0 ...  0  0  0]
#  [ 0 28  1 ...  0  0  4]
#  [ 0  1 41 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 49  0  0]
#  [ 0  0  0 ...  0 30  0]
#  [ 0 16  2 ...  0  0 17]]
#               precision    recall  f1-score   support
#
#            0       0.26      0.62      0.37       104
#            1       0.10      0.29      0.15        96
#            2       0.18      0.42      0.25        98
#            3       0.31      0.38      0.34       109
#            4       0.15      0.27      0.19       114
#            5       0.19      0.25      0.22       111
#            6       0.33      0.53      0.41        77
#            7       0.09      0.19      0.12       111
#            8       0.36      0.36      0.36        99
#            9       0.22      0.36      0.27       104
#           10       0.07      0.15      0.10        97
#           11       0.29      0.49      0.36        85
#           12       0.35      0.36      0.35        87
#           13       0.12      0.10      0.11       105
#           14       0.17      0.20      0.19        93
#           15       0.23      0.35      0.28        79
#           16       0.08      0.08      0.08        99
#           17       0.21      0.18      0.19       104
#           18       0.26      0.19      0.22        98
#           19       0.10      0.12      0.11       100
#           20       0.12      0.11      0.12       107
#           21       0.12      0.08      0.10       108
#           22       0.54      0.36      0.43       119
#           23       0.33      0.17      0.23        86
#           24       0.09      0.05      0.07        95
#           25       0.21      0.38      0.27        95
#           26       0.08      0.07      0.07        89
#           27       0.19      0.10      0.13       104
#           28       0.52      0.34      0.41       100
#           29       0.56      0.45      0.50       107
#           30       0.33      0.27      0.30       103
#           31       0.06      0.03      0.04       116
#           32       0.21      0.11      0.14       102
#           33       0.34      0.30      0.32        91
#           34       0.28      0.18      0.22        90
#           35       0.41      0.34      0.37       120
#           36       0.50      0.24      0.32       106
#           37       0.07      0.05      0.06       102
#           38       0.06      0.03      0.04        98
#           39       0.18      0.08      0.11       102
#           40       0.32      0.27      0.29        96
#           41       0.14      0.07      0.09        88
#           42       0.53      0.34      0.41        95
#           43       0.41      0.33      0.37        91
#           44       0.09      0.05      0.06       104
#           45       0.53      0.43      0.47       105
#           46       0.29      0.14      0.19       104
#           47       0.36      0.35      0.36        92
#           48       0.12      0.06      0.08        83
#           49       0.41      0.30      0.35        96
#           50       0.04      0.02      0.03        98
#           51       1.00      0.94      0.97        52
#           52       0.61      0.38      0.47        78
#           53       0.26      0.16      0.20       104
#
#     accuracy                           0.24      5296
#    macro avg       0.27      0.25      0.25      5296
# weighted avg       0.26      0.24      0.24      5296
#
# cv: 0.1686572270051659

# %%
DTC = DecisionTreeClassifier()
DTC.fit(x_train,y_train)

predDTC = DTC.predict(x_test)


print(accuracy_score(y_test, predDTC))
print(confusion_matrix(y_test, predDTC))
print(classification_report(y_test,predDTC))
print('cv:',cross_val_score(DTC,x,y,cv=5).mean())
# Out:
# 0.5479607250755287
# [[61  0  0 ...  0  0  0]
#  [ 0 41  1 ...  0  0  3]
#  [ 0  0 63 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 51  0  0]
#  [ 0  0  0 ...  0 59  0]
#  [ 0  1  7 ...  0  0 48]]
#               precision    recall  f1-score   support
#
#            0       0.57      0.59      0.58       104
#            1       0.42      0.43      0.42        96
#            2       0.59      0.64      0.62        98
#            3       0.59      0.56      0.57       109
#            4       0.48      0.48      0.48       114
#            5       0.51      0.45      0.48       111
#            6       0.71      0.83      0.77        77
#            7       0.54      0.50      0.52       111
#            8       0.79      0.73      0.76        99
#            9       0.53      0.56      0.54       104
#           10       0.32      0.32      0.32        97
#           11       0.65      0.64      0.64        85
#           12       0.50      0.59      0.54        87
#           13       0.45      0.45      0.45       105
#           14       0.53      0.54      0.53        93
#           15       0.61      0.54      0.57        79
#           16       0.41      0.53      0.46        99
#           17       0.54      0.54      0.54       104
#           18       0.64      0.60      0.62        98
#           19       0.45      0.48      0.47       100
#           20       0.55      0.38      0.45       107
#           21       0.55      0.44      0.49       108
#           22       0.75      0.74      0.75       119
#           23       0.57      0.57      0.57        86
#           24       0.42      0.39      0.40        95
#           25       0.57      0.60      0.58        95
#           26       0.35      0.38      0.37        89
#           27       0.43      0.46      0.44       104
#           28       0.69      0.66      0.68       100
#           29       0.82      0.78      0.80       107
#           30       0.60      0.63      0.62       103
#           31       0.34      0.30      0.32       116
#           32       0.47      0.47      0.47       102
#           33       0.45      0.51      0.48        91
#           34       0.57      0.61      0.59        90
#           35       0.77      0.77      0.77       120
#           36       0.49      0.48      0.49       106
#           37       0.38      0.42      0.40       102
#           38       0.34      0.32      0.33        98
#           39       0.43      0.41      0.42       102
#           40       0.75      0.67      0.71        96
#           41       0.53      0.56      0.54        88
#           42       0.79      0.78      0.78        95
#           43       0.59      0.54      0.56        91
#           44       0.43      0.42      0.43       104
#           45       0.72      0.73      0.73       105
#           46       0.59      0.64      0.62       104
#           47       0.60      0.61      0.60        92
#           48       0.39      0.47      0.43        83
#           49       0.67      0.65      0.66        96
#           50       0.30      0.34      0.32        98
#           51       0.96      0.98      0.97        52
#           52       0.80      0.76      0.78        78
#           53       0.48      0.46      0.47       104
#
#     accuracy                           0.55      5296
#    macro avg       0.56      0.55      0.55      5296
# weighted avg       0.55      0.55      0.55      5296
#
# cv: 0.28819905924298184

# %%
RFC = RandomForestClassifier()
RFC.fit(x_train,y_train)

predRFC = RFC.predict(x_test)

print(accuracy_score(y_test, predRFC))
print(confusion_matrix(y_test, predRFC))
print(classification_report(y_test,predRFC))
print('cv:',cross_val_score(RFC,x,y,cv=5).mean())
# Out:
# 0.6565332326283988
# [[77  0  0 ...  0  0  0]
#  [ 0 62  1 ...  0  0  8]
#  [ 0  0 61 ...  0  0  1]
#  ...
#  [ 0  0  0 ... 55  0  0]
#  [ 0  0  0 ...  0 68  0]
#  [ 0  4  1 ...  0  0 58]]
#               precision    recall  f1-score   support
#
#            0       0.68      0.83      0.75        93
#            1       0.61      0.53      0.57       117
#            2       0.77      0.70      0.73        87
#            3       0.62      0.54      0.58        92
#            4       0.80      0.70      0.75       100
#            5       0.77      0.64      0.70       112
#            6       0.89      0.99      0.94        84
#            7       0.49      0.58      0.53       101
#            8       0.83      0.89      0.86       104
#            9       0.53      0.76      0.62        86
#           10       0.51      0.39      0.44       103
#           11       0.66      0.78      0.71        94
#           12       0.76      0.75      0.76       101
#           13       0.59      0.62      0.61        93
#           14       0.61      0.71      0.65        97
#           15       0.79      0.67      0.72        84
#           16       0.53      0.46      0.49       112
#           17       0.60      0.69      0.64        94
#           18       0.63      0.65      0.64        95
#           19       0.59      0.63      0.61        97
#           20       0.59      0.60      0.59       108
#           21       0.58      0.66      0.62        91
#           22       0.86      0.86      0.86       112
#           23       0.67      0.75      0.71       103
#           24       0.55      0.54      0.55       106
#           25       0.79      0.75      0.77        99
#           26       0.52      0.55      0.54       104
#           27       0.56      0.59      0.57       102
#           28       0.77      0.72      0.75        98
#           29       0.89      0.89      0.89        94
#           30       0.75      0.70      0.73       105
#           31       0.40      0.44      0.42        97
#           32       0.70      0.58      0.64       113
#           33       0.56      0.55      0.56       106
#           34       0.63      0.63      0.63        93
#           35       0.75      0.83      0.79       111
#           36       0.70      0.56      0.62        99
#           37       0.62      0.53      0.57       123
#           38       0.50      0.40      0.44       113
#           39       0.43      0.45      0.44        92
#           40       0.66      0.82      0.73        93
#           41       0.63      0.60      0.61        87
#           42       0.84      0.89      0.86        87
#           43       0.74      0.68      0.71        98
#           44       0.52      0.48      0.50       104
#           45       0.74      0.84      0.78        85
#           46       0.70      0.71      0.70        90
#           47       0.66      0.68      0.67       106
#           48       0.61      0.55      0.58       104
#           49       0.80      0.74      0.77       106
#           50       0.35      0.32      0.33        91
#           51       1.00      1.00      1.00        55
#           52       0.87      0.89      0.88        76
#           53       0.57      0.59      0.58        99
#
#     accuracy                           0.66      5296
#    macro avg       0.66      0.66      0.66      5296
# weighted avg       0.66      0.66      0.65      5296
#
# cv: 0.3361265136071204

# %%
svc = SVC()
svc.fit(x_train,y_train)
predsvc = svc.predict(x_test)


print(accuracy_score(y_test, predsvc))
print(confusion_matrix(y_test, predsvc))
print(classification_report(y_test,predsvc))
print('cv:',cross_val_score(SVC,x,y,cv=5).mean())
# Out:
# 0.38557401812688824
# [[80  0  0 ...  0  0  0]
#  [ 0 25  0 ...  0  0  3]
#  [ 0  0 50 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 49  3  0]
#  [ 0  0  0 ...  0 41  0]
#  [ 0  4  2 ...  0  0 28]]
#               precision    recall  f1-score   support
#
#            0       0.32      0.77      0.45       104
#            1       0.22      0.26      0.24        96
#            2       0.51      0.51      0.51        98
#            3       0.55      0.31      0.40       109
#            4       0.51      0.31      0.38       114
#            5       0.69      0.23      0.34       111
#            6       0.66      0.74      0.70        77
#            7       0.25      0.26      0.26       111
#            8       0.60      0.65      0.62        99
#            9       0.37      0.56      0.44       104
#           10       0.26      0.25      0.26        97
#           11       0.35      0.52      0.42        85
#           12       0.46      0.47      0.46        87
#           13       0.26      0.31      0.29       105
#           14       0.34      0.45      0.39        93
#           15       0.51      0.46      0.48        79
#           16       0.17      0.17      0.17        99
#           17       0.29      0.37      0.32       104
#           18       0.34      0.34      0.34        98
#           19       0.30      0.42      0.35       100
#           20       0.25      0.17      0.20       107
#           21       0.21      0.18      0.19       108
#           22       0.79      0.51      0.62       119
#           23       0.38      0.49      0.42        86
#           24       0.28      0.20      0.23        95
#           25       0.34      0.60      0.43        95
#           26       0.13      0.15      0.14        89
#           27       0.27      0.17      0.21       104
#           28       0.58      0.56      0.57       100
#           29       0.67      0.69      0.68       107
#           30       0.40      0.52      0.45       103
#           31       0.28      0.04      0.07       116
#           32       0.44      0.30      0.36       102
#           33       0.38      0.43      0.40        91
#           34       0.21      0.26      0.23        90
#           35       0.50      0.64      0.56       120
#           36       0.58      0.33      0.42       106
#           37       0.18      0.22      0.19       102
#           38       0.14      0.16      0.15        98
#           39       0.25      0.31      0.28       102
#           40       0.44      0.47      0.45        96
#           41       0.33      0.12      0.18        88
#           42       0.67      0.60      0.63        95
#           43       0.46      0.55      0.50        91
#           44       0.19      0.22      0.20       104
#           45       0.59      0.70      0.64       105
#           46       0.58      0.30      0.39       104
#           47       0.45      0.54      0.50        92
#           48       0.18      0.07      0.10        83
#           49       0.51      0.44      0.47        96
#           50       0.23      0.18      0.20        98
#           51       1.00      0.94      0.97        52
#           52       0.72      0.53      0.61        78
#           53       0.28      0.27      0.27       104
#
#     accuracy                           0.39      5296
#    macro avg       0.41      0.39      0.38      5296
# weighted avg       0.40      0.39      0.38      5296
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:822, in Parallel.dispatch_one_batch(self, iterator)
#     821 try:
# --> 822     tasks = self._ready_batches.get(block=False)
#     823 except queue.Empty:
#     824     # slice the iterator n_jobs * batchsize items at a time. If the
#     825     # slice returns less than that, then the current batchsize puts
#    (...)
#     828     # accordingly to distribute evenly the last items between all
#     829     # workers.
#
# File ~\anaconda3\lib\queue.py:168, in Queue.get(self, block, timeout)
#     167     if not self._qsize():
# --> 168         raise Empty
#     169 elif timeout is None:
#
# Empty:
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Input In [33], in <cell line: 9>()
#       7 print(confusion_matrix(y_test, predsvc))
#       8 print(classification_report(y_test,predsvc))
# ----> 9 print('cv:',cross_val_score(SVC,x,y,cv=5).mean())
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:509, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     506 # To ensure multimetric format is not supported
#     507 scorer = check_scoring(estimator, scoring=scoring)
# --> 509 cv_results = cross_validate(
#     510     estimator=estimator,
#     511     X=X,
#     512     y=y,
#     513     groups=groups,
#     514     scoring={"score": scorer},
#     515     cv=cv,
#     516     n_jobs=n_jobs,
#     517     verbose=verbose,
#     518     fit_params=fit_params,
#     519     pre_dispatch=pre_dispatch,
#     520     error_score=error_score,
#     521 )
#     522 return cv_results["test_score"]
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:267, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     264 # We clone the estimator to make sure that all the folds are
#     265 # independent, and that it is pickle-able.
#     266 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 267 results = parallel(
#     268     delayed(_fit_and_score)(
#     269         clone(estimator),
#     270         X,
#     271         y,
#     272         scorers,
#     273         train,
#     274         test,
#     275         verbose,
#     276         None,
#     277         fit_params,
#     278         return_train_score=return_train_score,
#     279         return_times=True,
#     280         return_estimator=return_estimator,
#     281         error_score=error_score,
#     282     )
#     283     for train, test in cv.split(X, y, groups)
#     284 )
#     286 _warn_about_fit_failures(results, error_score)
#     288 # For callabe scoring, the return type is only know after calling. If the
#     289 # return type is a dictionary, the error scores can now be inserted with
#     290 # the correct key.
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:1043, in Parallel.__call__(self, iterable)
#    1034 try:
#    1035     # Only set self._iterating to True if at least a batch
#    1036     # was dispatched. In particular this covers the edge
#    (...)
#    1040     # was very quick and its callback already dispatched all the
#    1041     # remaining jobs.
#    1042     self._iterating = False
# -> 1043     if self.dispatch_one_batch(iterator):
#    1044         self._iterating = self._original_iterator is not None
#    1046     while self.dispatch_one_batch(iterator):
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:833, in Parallel.dispatch_one_batch(self, iterator)
#     830 n_jobs = self._cached_effective_n_jobs
#     831 big_batch_size = batch_size * n_jobs
# --> 833 islice = list(itertools.islice(iterator, big_batch_size))
#     834 if len(islice) == 0:
#     835     return False
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:269, in <genexpr>(.0)
#     264 # We clone the estimator to make sure that all the folds are
#     265 # independent, and that it is pickle-able.
#     266 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
#     267 results = parallel(
#     268     delayed(_fit_and_score)(
# --> 269         clone(estimator),
#     270         X,
#     271         y,
#     272         scorers,
#     273         train,
#     274         test,
#     275         verbose,
#     276         None,
#     277         fit_params,
#     278         return_train_score=return_train_score,
#     279         return_times=True,
#     280         return_estimator=return_estimator,
#     281         error_score=error_score,
#     282     )
#     283     for train, test in cv.split(X, y, groups)
#     284 )
#     286 _warn_about_fit_failures(results, error_score)
#     288 # For callabe scoring, the return type is only know after calling. If the
#     289 # return type is a dictionary, the error scores can now be inserted with
#     290 # the correct key.
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:70, in clone(estimator, safe)
#      68 else:
#      69     if isinstance(estimator, type):
# ---> 70         raise TypeError(
#      71             "Cannot clone object. "
#      72             + "You should provide an instance of "
#      73             + "scikit-learn estimator instead of a class."
#      74         )
#      75     else:
#      76         raise TypeError(
#      77             "Cannot clone object '%s' (type %s): "
#      78             "it does not seem to be a scikit-learn "
#      79             "estimator as it does not implement a "
#      80             "'get_params' method." % (repr(estimator), type(estimator))
#      81         )
#
# TypeError: Cannot clone object. You should provide an instance of scikit-learn estimator instead of a class.

# %%
ABC = AdaBoostClassifier()
ABC.fit(x_train,y_train)

predABC = ABC.predict(x_test)


print(accuracy_score(y_test, predABC))
print(confusion_matrix(y_test, predABC))
print(classification_report(y_test,predABC))
print('cv:',cross_val_score(ABC,x,y,cv=5).mean())
# Out:
# 0.050981873111782476
# [[ 2  0  0 ...  0  0  0]
#  [ 0 12  0 ...  5  0  0]
#  [ 0 12 22 ... 41  0  0]
#  ...
#  [ 0  0  0 ...  0  0  0]
#  [ 0  5  0 ... 33  0  0]
#  [ 0 25  5 ... 44  0  0]]
#               precision    recall  f1-score   support
#
#            0       0.02      0.02      0.02       104
#            1       0.04      0.12      0.06        96
#            2       0.09      0.22      0.13        98
#            3       0.00      0.00      0.00       109
#            4       0.00      0.00      0.00       114
#            5       0.00      0.00      0.00       111
#            6       0.00      0.00      0.00        77
#            7       0.00      0.00      0.00       111
#            8       0.00      0.00      0.00        99
#            9       0.00      0.00      0.00       104
#           10       0.05      0.43      0.10        97
#           11       0.00      0.00      0.00        85
#           12       0.09      0.18      0.12        87
#           13       0.00      0.00      0.00       105
#           14       0.00      0.00      0.00        93
#           15       0.00      0.00      0.00        79
#           16       0.00      0.00      0.00        99
#           17       0.09      0.08      0.08       104
#           18       0.00      0.00      0.00        98
#           19       0.00      0.00      0.00       100
#           20       0.00      0.00      0.00       107
#           21       0.00      0.00      0.00       108
#           22       0.28      0.18      0.22       119
#           23       0.00      0.00      0.00        86
#           24       0.00      0.00      0.00        95
#           25       0.10      0.46      0.17        95
#           26       0.00      0.00      0.00        89
#           27       0.00      0.00      0.00       104
#           28       0.00      0.00      0.00       100
#           29       0.00      0.00      0.00       107
#           30       0.00      0.00      0.00       103
#           31       0.00      0.00      0.00       116
#           32       0.00      0.00      0.00       102
#           33       0.00      0.00      0.00        91
#           34       0.04      0.42      0.08        90
#           35       0.00      0.00      0.00       120
#           36       0.00      0.00      0.00       106
#           37       0.00      0.00      0.00       102
#           38       0.00      0.00      0.00        98
#           39       0.00      0.00      0.00       102
#           40       0.00      0.00      0.00        96
#           41       0.00      0.00      0.00        88
#           42       0.00      0.00      0.00        95
#           43       0.00      0.00      0.00        91
#           44       0.10      0.35      0.15       104
#           45       0.00      0.00      0.00       105
#           46       0.00      0.00      0.00       104
#           47       0.00      0.00      0.00        92
#           48       0.00      0.00      0.00        83
#           49       0.03      0.24      0.06        96
#           50       0.02      0.05      0.03        98
#           51       0.00      0.00      0.00        52
#           52       0.00      0.00      0.00        78
#           53       0.00      0.00      0.00       104
#
#     accuracy                           0.05      5296
#    macro avg       0.02      0.05      0.02      5296
# weighted avg       0.02      0.05      0.02      5296
#
# cv: 0.057218853970859476

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter = {  'bootstrap': [True], 'max_depth': [5, 10,20,40,50, None], 
              'max_features': ['auto', 'log2'], 
              'criterion':['gini','entropy'],
              'n_estimators': [5, 10, 15 ,25,50,100]}

# %%
GCV = GridSearchCV(RandomForestClassifier(),parameter,cv=5,n_jobs = -1,verbose=3)
GCV.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'bootstrap': [True], 'criterion': ['gini', 'entropy'],
#                          'max_depth': [5, 10, 20, 40, 50, None],
#                          'max_features': ['auto', 'log2'],
#                          'n_estimators': [5, 10, 15, 25, 50, 100]},
#              verbose=3)

# %%
gridSearchCV.fit(x_train,y_train)

# %%
GCV.best_score_
GCV.best_params_
# Out:
# {'bootstrap': True,
#  'criterion': 'entropy',
#  'max_depth': 40,
#  'max_features': 'log2',
#  'n_estimators': 100}

# %%
Final = RandomForestClassifier(bootstrap=True,criterion='entropy',n_estimators= 100, max_depth=40 ,max_features='log2')
Final.fit(x_train,y_train)
y_pred=Final.predict(x_test)
print('Accuracy Score :', accuracy_score(y_test, y_pred))
# Out:
# Accuracy Score : 0.9097432024169184

# %%
score=cross_val_score(RandomForestClassifier(),x,y,cv=100,scoring='accuracy').mean()
print("Cross val score :",score*100)
print("Mean score :", (score.mean())*100)
print("STD :", score.std()*100)
# Out:
# Cross val score : 61.674274524910125
# Mean score : 61.674274524910125
# STD : 0.0

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

y_pred_prob = Final.predict_proba(x_test)[:,1]
fpr, tpr, thresholds = roc_curve(y_test,y_pred_prob,pos_label=True)
plt.plot([0,1],[0,1], 'k--')
plt.plot(fpr, tpr, label='Random Forest Classifier')
plt.xlabel('False postive rate')
plt.ylabel('True postive rate')
plt.show()

# %%
import joblib
joblib.dump(Final,'Avacadoclassifier.pkl')
# Out:
# ['Avacadoclassifier.pkl']

# %% [markdown]
# # Averagae price as target variable

# %%
df2.head()
# Out:
#    AveragePrice  Total Volume  Small Bags  Large Bags  XLarge Bags  type  \
# 0          1.33     -0.075324   -0.347421   -0.781153    -0.677919     0
# 1          1.35     -0.147497   -0.311322   -0.771198    -0.677919     0
# 2          0.93      0.205556   -0.374453   -0.758523    -0.677919     0
# 3          1.08      0.019655   -0.510991   -0.699123    -0.677919     0
# 4          1.28     -0.180674   -0.490534   -0.607027    -0.677919     0
#
#    region  Month  Date
# 0       0     12    27
# 1       0     12    20
# 2       0     12    13
# 3       0     12     6
# 4       0     11    29

# %% [markdown]
# # univariant analysis

# %%
sns.set_palette('cool')
plt.figure(figsize=(20,30), facecolor='white')
plotnumber =1
for column in df:
    if plotnumber <=17:
        ax = plt.subplot(6,3,plotnumber)
        sns.histplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# # bivariant analysis

# %%
plt.figure(figsize=(15,200))
j = 0
for column, dtype in df.drop('AveragePrice',axis=1).dtypes.items():

    if dtype != 'object':
        j += 1
        plt.subplot(40,2,j)
        sns.scatterplot(df['AveragePrice'],df[column])

# %% [markdown]
# # multivariant analysis

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='AveragePrice', y='Total Volume', hue='type',data=df, palette='coolwarm',ci=68)
plt.show()

# %%
pd.crosstab([df.type,df.year],df.AveragePrice, margins= True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_d96de_row0_col0, #T_d96de_row0_col1, #T_d96de_row0_col2, #T_d96de_row0_col8, #T_d96de_row0_col12, #T_d96de_row0_col94, #T_d96de_row0_col95, #T_d96de_row0_col99, #T_d96de_row0_col102, #T_d96de_row0_col104, #T_d96de_row0_col106, #T_d96de_row0_col108, #T_d96de_row0_col110, #T_d96de_row0_col113, #T_d96de_row0_col114, #T_d96de_row0_col115, #T_d96de_row0_col116, #T_d96de_row0_col117, #T_d96de_row0_col118, #T_d96de_row0_col119, #T_d96de_row0_col120, #T_d96de_row0_col121, #T_d96de_row0_col122, #T_d96de_row0_col123, #T_d96de_row0_col124, #T_d96de_row0_col125, #T_d96de_row0_col126, #T_d96de_row0_col127, #T_d96de_row0_col128, #T_d96de_row0_col129, #T_d96de_row0_col130, #T_d96de_row0_col131, #T_d96de_row0_col132, #T_d96de_row0_col133, #T_d96de_row0_col134, #T_d96de_row0_col135, #T_d96de_row0_col136, #T_d96de_row0_col137, #T_d96de_row0_col138, #T_d96de_row0_col139, #T_d96de_row0_col140, #T_d96de_row0_col141, #T_d96de_row0_col142, #T_d96de_row0_col143, #T_d96de_row0_col144, #T_d96de_row0_col145, #T_d96de_row0_col146, #T_d96de_row0_col147, #T_d96de_row0_col148, #T_d96de_row0_col149, #T_d96de_row0_col150, #T_d96de_row0_col151, #T_d96de_row0_col152, #T_d96de_row0_col153, #T_d96de_row0_col154, #T_d96de_row0_col155, #T_d96de_row0_col156, #T_d96de_row0_col157, #T_d96de_row0_col158, #T_d96de_row0_col159, #T_d96de_row0_col160, #T_d96de_row0_col161, #T_d96de_row0_col162, #T_d96de_row0_col163, #T_d96de_row0_col164, #T_d96de_row0_col165, #T_d96de_row0_col166, #T_d96de_row0_col167, #T_d96de_row0_col168, #T_d96de_row0_col169, #T_d96de_row0_col170, #T_d96de_row0_col171, #T_d96de_row0_col172, #T_d96de_row0_col173, #T_d96de_row0_col174, #T_d96de_row0_col175, #T_d96de_row0_col176, #T_d96de_row0_col177, #T_d96de_row0_col178, #T_d96de_row0_col179, #T_d96de_row0_col180, #T_d96de_row0_col181, #T_d96de_row0_col182, #T_d96de_row0_col183, #T_d96de_row0_col184, #T_d96de_row0_col185, #T_d96de_row0_col186, #T_d96de_row0_col187, #T_d96de_row0_col188, #T_d96de_row0_col189, #T_d96de_row0_col190, #T_d96de_row0_col191, #T_d96de_row0_col192, #T_d96de_row0_col193, #T_d96de_row0_col194, #T_d96de_row0_col195, #T_d96de_row0_col196, #T_d96de_row0_col197, #T_d96de_row0_col198, #T_d96de_row0_col199, #T_d96de_row0_col200, #T_d96de_row0_col201, #T_d96de_row0_col202, #T_d96de_row0_col203, #T_d96de_row0_col204, #T_d96de_row0_col205, #T_d96de_row0_col206, #T_d96de_row0_col207, #T_d96de_row0_col208, #T_d96de_row0_col209, #T_d96de_row0_col210, #T_d96de_row0_col211, #T_d96de_row0_col212, #T_d96de_row0_col213, #T_d96de_row0_col214, #T_d96de_row0_col215, #T_d96de_row0_col216, #T_d96de_row0_col217, #T_d96de_row0_col218, #T_d96de_row0_col219, #T_d96de_row0_col220, #T_d96de_row0_col221, #T_d96de_row0_col222, #T_d96de_row0_col223, #T_d96de_row0_col224, #T_d96de_row0_col225, #T_d96de_row0_col226, #T_d96de_row0_col227, #T_d96de_row0_col228, #T_d96de_row0_col229, #T_d96de_row0_col230, #T_d96de_row0_col231, #T_d96de_row0_col232, #T_d96de_row0_col233, #T_d96de_row0_col234, #T_d96de_row0_col235, #T_d96de_row0_col236, #T_d96de_row0_col237, #T_d96de_row0_col238, #T_d96de_row0_col239, #T_d96de_row0_col240, #T_d96de_row0_col241, #T_d96de_row0_col242, #T_d96de_row0_col243, #T_d96de_row0_col244, #T_d96de_row0_col245, #T_d96de_row0_col246, #T_d96de_row0_col247, #T_d96de_row0_col248, #T_d96de_row0_col249, #T_d96de_row0_col250, #T_d96de_row0_col251, #T_d96de_row0_col252, #T_d96de_row0_col253, #T_d96de_row0_col254, #T_d96de_row0_col255, #T_d96de_row0_col256, #T_d96de_row0_col257, #T_d96de_row0_col258, #T_d96de_row1_col0, #T_d96de_row1_col1, #T_d96de_row1_col2, #T_d96de_row1_col3, #T_d96de_row1_col5, #T_d96de_row1_col6, #T_d96de_row1_col130, #T_d96de_row1_col141, #T_d96de_row1_col144, #T_d96de_row1_col145, #T_d96de_row1_col149, #T_d96de_row1_col150, #T_d96de_row1_col151, #T_d96de_row1_col153, #T_d96de_row1_col154, #T_d96de_row1_col155, #T_d96de_row1_col156, #T_d96de_row1_col157, #T_d96de_row1_col158, #T_d96de_row1_col159, #T_d96de_row1_col161, #T_d96de_row1_col162, #T_d96de_row1_col163, #T_d96de_row1_col164 ...

# %%
df.groupby(['year','type'])['AveragePrice'].agg([min,max,np.mean,np.median])
# Out:
#                     min   max      mean  median
# year type
# 2015 conventional  0.49  1.59  1.077963    1.08
#      organic       0.81  2.79  1.673324    1.67
# 2016 conventional  0.51  2.20  1.105595    1.08
#      organic       0.58  3.25  1.571684    1.53
# 2017 conventional  0.46  2.22  1.294888    1.30
#      organic       0.44  3.17  1.735521    1.72
# 2018 conventional  0.56  1.74  1.127886    1.14
#      organic       1.01  2.30  1.567176    1.55

# %% [raw]
# Conventional Avacado are in more demand.
# The Average price varies over year and season

# %% [raw]
# Except 2017 each year their is incresase in price of avacado

# %%
df.drop(['Date','type','region'], axis=1, inplace=True)

# %%
sns.pairplot(df)

# %%
plt.figure(figsize = (18,6))
df.corr()['AveragePrice'].drop(['AveragePrice']).plot(kind='bar',color = 'c')
plt.xlabel('Features',fontsize=15)
plt.ylabel('AveragePrice',fontsize=15)
plt.show()

# %%
X = df.drop('AveragePrice', axis=1)
Y = df['AveragePrice']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)
X.head()
# Out:
#    Total Volume  Small Bags  Large Bags  XLarge Bags      type    region  \
# 0     -0.075324   -0.347421   -0.781153    -0.677919 -1.019047 -1.695495
# 1     -0.147497   -0.311322   -0.771198    -0.677919 -1.019047 -1.695495
# 2      0.205556   -0.374453   -0.758523    -0.677919 -1.019047 -1.695495
# 3      0.019655   -0.510991   -0.699123    -0.677919 -1.019047 -1.695495
# 4     -0.180674   -0.490534   -0.607027    -0.677919 -1.019047 -1.695495
#
#       Month      Date
# 0  1.644612  1.289309
# 1  1.644612  0.491652
# 2  1.644612 -0.306004
# 3  1.644612 -1.103660
# 4  1.362113  1.517211

# %% [markdown]
# # multicollinearity detection

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["Features"]=X.columns
vif["VIF Value"]=[variance_inflation_factor(X.values,i) for i in range(len(X.columns))]
vif
# Out:
#        Features  VIF Value
# 0  Total Volume   9.717337
# 1    Small Bags   5.849157
# 2    Large Bags   1.976123
# 3   XLarge Bags   1.936103
# 4          type   3.264060
# 5        region   1.024585
# 6         Month   1.004816
# 7          Date   1.000759

# %% [markdown]
# # building regression model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import  GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import  Ridge
from sklearn.linear_model import  Lasso

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state=42, test_size=.33)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
maxR2_score=0
maxRS=0
for i in range(1,1000):
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state=i, test_size=.33)
    lin_reg=LinearRegression()
    lin_reg.fit(X_train,Y_train)
    y_pred=lin_reg.predict(X_test)
    R2=r2_score(Y_test,y_pred)
    if R2>maxR2_score:
        maxR2_score=R2
        maxRS=i
print('Best R2 Score is', maxR2_score ,'on Random_state', maxRS)
# Out:
# Best R2 Score is 0.47138199361742605 on Random_state 449

# %%
from sklearn.model_selection import cross_val_score
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state=449, test_size=.33)

# %%
lin_reg=LinearRegression()
rf = RandomForestRegressor(n_estimators = 70 ,max_depth=25)
dtc = DecisionTreeRegressor()
adb=AdaBoostRegressor(learning_rate=0.1)
gradb=GradientBoostingRegressor(max_depth=25,learning_rate=0.1)
rd=Ridge(alpha=0.01)
model = [lin_reg,rf,rd,dtc,adb,gradb]

for m in model:
    m.fit(X_train,Y_train)
    m.score(X_train,Y_train)
    y_pred = m.predict(X_test)
    print('\n')                                        
    print('\033[1m'+' Error of ', m, ':' +'\033[0m')
    print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
    print('Mean squared error :', mean_squared_error(Y_test,y_pred))
    print('Root Mean Squared Error:', np.sqrt(mean_squared_error(Y_test,y_pred)))
    print('\n')

    print('\033[1m'+' R2 Score :'+'\033[0m')
    print(r2_score(Y_test,y_pred))
    
    score = cross_val_score(m, X, Y, cv =5)
    print("Mean CV Score :",score.mean())
    print('==============================================================================================================')
# Out:
#  Error of  LinearRegression() :
# Mean absolute error : 0.21992798798241842
# Mean squared error : 0.07711385980239391
# Root Mean Squared Error: 0.27769382384632524
#
#
#  R2 Score :
# 0.49431732486870916
# Mean CV Score : 0.08294859819673797
# ==============================================================================================================
#
#
#  Error of  RandomForestRegressor(max_depth=25, n_estimators=70) :
# Mean absolute error : 0.09938917962646508
# Mean squared error : 0.019348822035726694
# Root Mean Squared Error: 0.13910004326284983
#
#
#  R2 Score :
# 0.8731179568402074
# Mean CV Score : 0.1354816845572129
# ==============================================================================================================
#
#
#  Error of  Ridge(alpha=0.01) :
# Mean absolute error : 0.2199279899741073
# Mean squared error : 0.0771138632800411
# Root Mean Squared Error: 0.2776938301079826
#
#
#  R2 Score :
# 0.49431730206365265
# Mean CV Score : 0.0829487415730823
# ==============================================================================================================
#
#
#  Error of  DecisionTreeRegressor() :
# Mean absolute error : 0.13411502145922746
# Mean squared error : 0.04119000858369099
# Root Mean Squared Error: 0.20295321772194447
#
#
#  R2 Score :
# 0.7298919573905822
# Mean CV Score : -0.25137812476572735
# ==============================================================================================================
#
#
#  Error of  AdaBoostRegressor(learning_rate=0.1) :
# Mean absolute error : 0.20925078143928796
# Mean squared error : 0.07069690294631391
# Root Mean Squared Error: 0.26588889210780114
#
#
#  R2 Score :
# 0.5363972300569576
# Mean CV Score : 0.052774007067852645
# ==============================================================================================================
#
#
#  Error of  GradientBoostingRegressor(max_depth=25) :
# Mean absolute error : 0.12871788867836195
# Mean squared error : 0.03744521940907653
# Root Mean Squared Error: 0.19350767273954936
#
#
#  R2 Score :
# 0.7544488270956433
# Mean CV Score : -0.206715339246459
# ==============================================================================================================

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter = {'n_estimators':[50,60,80],'max_depth': [10,20,40],
            'criterion':['mse','mae'],'min_samples_leaf': [5,10,15],
             'min_samples_split':[5,10,15,20],
             'max_features':["auto","sqrt","log2"]}

# %%
GCV = GridSearchCV(RandomForestRegressor(),parameter,cv=3,verbose = 3)

# %%
GCV.fit(X_train,Y_train)
# Out:
# Fitting 3 folds for each of 648 candidates, totalling 1944 fits
# [CV 1/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=0.695 total time=   1.8s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=0.729 total time=   1.8s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=0.712 total time=   1.9s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=60;, score=0.692 total time=   2.0s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=60;, score=0.726 total time=   2.3s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=60;, score=0.713 total time=   2.1s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=80;, score=0.693 total time=   2.9s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=80;, score=0.728 total time=   2.5s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=80;, score=0.713 total time=   2.4s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=0.695 total time=   1.4s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=0.730 total time=   1.4s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=0.712 total time=   1.4s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=60;, score=0.692 total time=   1.8s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=60;, score=0.725 total time=   1.7s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=60;, score=0.714 total time=   1.7s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=80;, score=0.697 total time=   2.5s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=80;, score=0.729 total time=   2.3s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=80;, score=0.714 total time=   2.3s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=50;, score=0.690 total time=   1.4s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=50;, score=0.723 total time=   1.4s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=50;, score=0.708 total time=   1.4s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=60;, score=0.689 total time=   1.7s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=60;, score=0.725 total time=   1.7s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=60;, score=0.705 total time=   1.7s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=80;, score=0.691 total time=   2.3s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=80;, score=0.724 total time=   2.3s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=80;, score=0.707 total time=   2.3s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=20, n_estimators=50;, score=0.682 total time=   1.4s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=20, n_estimators=50;, score=0.717 total time=   1.4s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=20, n_estimators=50;, score=0.699 total time=   1.4s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=20, n_estimators=60;, score=0.684 total time=   1.7s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=20, n_estimators=60;, score=0.718 total time=   1.7s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=20, n_estimators=60;, score=0.701 total time=   1.7s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=20, n_estimators=80;, score=0.682 total time=   2.3s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=20, n_estimators=80;, score=0.715 total time=   2.3s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=20, n_estimators=80;, score=0.702 total time=   2.2s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=0.677 total time=   1.3s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=0.711 total time=   1.4s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=0.693 total time=   1.3s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=60;, score=0.677 total time=   1.6s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=60;, score=0.712 total time=   1.6s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=60;, score=0.697 total time=   1.6s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=80;, score=0.675 total time=   2.2s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=80;, score=0.712 total time=   2.2s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=80;, score=0.699 total time=   2.2s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.676 total time=   1.4s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.712 total time=   1.3s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.700 total time=   1.4s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=60;, score=0.675 total time=   1.6s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=60;, score=0.714 total time=   1.6s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=60;, score=0.695 total time=   1.6s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=80;, score=0.678 total time=   2.2s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=80;, score=0.712 total time=   2.2s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=80;, score=0.696 total time=   2.2s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=15, n_estimators=50;, score=0.676 total time=   1.3s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=15, n_estimators=50;, score=0.710 total time=   1.4s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=15, n_estimators=50;, score=0.695 total time=   1.3s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=15, n_estimators=60;, score=0.675 total time=   1.6s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=15, n_estimators=60;, score=0.710 total time=   1.6s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=15, n_estimators=60;, score=0.696 total time=   1.6s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=15, n_estimators=80;, score=0.678 total time=   2.2s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=15, n_estimators=80;, score=0.712 total time=   2.2s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=15, n_estimators=80;, score=0.699 total time=   2.2s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=50;, score=0.678 total time=   1.3s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=50;, score=0.711 total time=   1.3s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=50;, score=0.695 total time=   1.4s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=60;, score=0.675 total time=   1.9s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=60;, score=0.712 total time=   1.7s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=60;, score=0.697 total time=   1.7s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=80;, score=0.680 total time=   2.3s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=80;, score=0.716 total time=   2.3s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=80;, score=0.695 total time=   2.3s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=15, min_samples_split=5, n_estimators=50;, score=0.654 total time=   1.3s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=15, min_samples_split=5, n_estimators=50;, score=0.698 total time=   1.3s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=15, min_samples_split=5, n_estimators=50;, score=0.681 total time=   1.3s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=15, min_samples_split=5, n_estimators=60;, score=0.662 total time=   1.6s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=15, min_samples_split=5, n_estimators=60;, score=0.696 total time=   1.6s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=15, min_samples_split=5, n_estimators=60;, score=0.679 total time=   1.6s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=15, min_samples_split=5, n_estimators=80;, score=0.660 total time=   2.1s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=15, min_samples_split=5, n_estimators=80;, score=0.696 total time=   2.1s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=15, min_samples_split=5, n_estimators=80;, score=0.681 total time=   2.3s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=15, min_samples_split=10, n_estimators=50;, score=0.662 total time=   1.3s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=15, min_samples_split=10, n_estimators=50;, score=0.697 total time=   1.3s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=15, min_samples_split=10, n_estimators=50;, score=0.677 total time=   1.3s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=15, min_samples_split=10, n_estimators=60;, score=0.660 total time=   1.6s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=15, min_samples_split=10, n_estimators=60;, score=0.696 total time=   1.6s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=15, min_samples_split=10, n_estimators=60;, score=0.677 total time=   1.6s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=15, min_samples_split=10, n_estimators=80;, score=0.659 total time=   2.1s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=15, min_samples_split=10, n_estimators=80;, score=0.695 total time=   2.1s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=15, min_samples_split=10, n_estimators=80;, score=0.680 total time=   2.2s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=15, min_samples_split=15, n_estimators=50;, score=0.661 total time=   1.3s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=15, min_samples_split=15, n_estimators=50;, score=0.696 total time=   1.3s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=15, min_samples_split=15, n_estimators=50;, score=0.679 total time=   1.4s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=15, min_samples_split=15, n_estimators=60;, score=0.660 total time=   1.6s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=15, min_samples_split=15, n_estimators=60;, score=0.696 total time=   1.6s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=15, min_samples_split=15, n_estimators=60;, score=0.680 total time=   1.6s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=15, min_samples_split=15, n_estimators=80;, score=0.658 total time=   2.1s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=15, min_samples_split=15, n_estimators=80;, score=0.698 total time=   2.1s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=15, min_samples_split=15, n_estimators=80;, score=0.678 total time=   2.2s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=15, min_samples_split=20, n_estimators=50;, score=0.655 total time=   1.3s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=15, min_samples_split=20, n_estimators=50;, score=0.696 total time=   1.3s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=15, min_samples_split=20, n_estimators=50;, score=0.680 total time=   1.3s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=15, min_samples_split=20, n_estimators=60;, score=0.658 total time=   1.6s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=15, min_samples_split=20, n_estimators=60;, score=0.699 total time=   1.6s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=15, min_samples_split=20, n_estimators=60;, score=0.679 total time=   1.6s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=15, min_samples_split=20, n_estimators=80;, score=0.657 total time=   2.1s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=15, min_samples_split=20, n_estimators=80;, score=0.697 total time=   2.2s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=auto, min_samples_leaf=15, min_samples_split=20, n_estimators=80;, score=0.678 total time=   2.2s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=0.629 total time=   0.5s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=0.660 total time=   0.4s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=0.639 total time=   0.4s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=60;, score=0.629 total time=   0.6s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=60;, score=0.652 total time=   0.6s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=60;, score=0.642 total time=   0.6s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=80;, score=0.627 total time=   0.8s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=80;, score=0.653 total time=   0.8s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=80;, score=0.641 total time=   0.8s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=0.627 total time=   0.6s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=0.654 total time=   0.4s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=0.640 total time=   0.5s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=60;, score=0.627 total time=   0.6s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=60;, score=0.649 total time=   0.6s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=60;, score=0.637 total time=   0.5s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=80;, score=0.622 total time=   0.8s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=80;, score=0.655 total time=   0.9s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=80;, score=0.640 total time=   0.7s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=50;, score=0.624 total time=   0.4s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=50;, score=0.654 total time=   0.4s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=50;, score=0.639 total time=   0.4s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=60;, score=0.628 total time=   0.5s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=60;, score=0.652 total time=   0.5s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=60;, score=0.635 total time=   0.5s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=80;, score=0.626 total time=   0.8s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=80;, score=0.657 total time=   0.7s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=80;, score=0.639 total time=   0.7s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=50;, score=0.617 total time=   0.4s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=50;, score=0.653 total time=   0.4s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=50;, score=0.634 total time=   0.4s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=60;, score=0.617 total time=   0.6s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=60;, score=0.649 total time=   0.7s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=60;, score=0.635 total time=   0.7s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=80;, score=0.619 total time=   0.9s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=80;, score=0.645 total time=   0.9s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=20, n_estimators=80;, score=0.633 total time=   0.8s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=0.612 total time=   0.4s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=0.644 total time=   0.4s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=0.625 total time=   0.5s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=60;, score=0.605 total time=   0.5s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=60;, score=0.642 total time=   0.6s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=60;, score=0.627 total time=   0.5s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=80;, score=0.614 total time=   0.7s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=80;, score=0.638 total time=   0.8s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=80;, score=0.622 total time=   1.0s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.611 total time=   0.6s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.645 total time=   0.5s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.626 total time=   0.6s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=60;, score=0.615 total time=   0.7s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=60;, score=0.643 total time=   0.7s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=60;, score=0.624 total time=   0.7s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=80;, score=0.609 total time=   0.7s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=80;, score=0.640 total time=   0.7s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=80;, score=0.625 total time=   0.7s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=50;, score=0.611 total time=   0.4s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=50;, score=0.639 total time=   0.4s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=50;, score=0.629 total time=   0.4s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=60;, score=0.615 total time=   0.5s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=60;, score=0.637 total time=   0.5s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=60;, score=0.626 total time=   0.5s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=80;, score=0.612 total time=   0.8s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=80;, score=0.643 total time=   0.7s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=80;, score=0.630 total time=   0.7s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=50;, score=0.604 total time=   0.4s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=50;, score=0.636 total time=   0.4s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=50;, score=0.631 total time=   0.5s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=60;, score=0.608 total time=   0.5s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=60;, score=0.640 total time=   0.5s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=60;, score=0.625 total time=   0.5s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=80;, score=0.612 total time=   0.7s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=80;, score=0.638 total time=   0.7s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=10, min_samples_split=20, n_estimators=80;, score=0.626 total time=   0.8s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=5, n_estimators=50;, score=0.597 total time=   0.4s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=5, n_estimators=50;, score=0.628 total time=   0.4s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=5, n_estimators=50;, score=0.609 total time=   0.4s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=5, n_estimators=60;, score=0.598 total time=   0.5s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=5, n_estimators=60;, score=0.621 total time=   0.5s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=5, n_estimators=60;, score=0.609 total time=   0.5s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=5, n_estimators=80;, score=0.596 total time=   0.7s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=5, n_estimators=80;, score=0.626 total time=   0.7s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=5, n_estimators=80;, score=0.611 total time=   0.7s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=10, n_estimators=50;, score=0.598 total time=   0.4s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=10, n_estimators=50;, score=0.629 total time=   0.4s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=10, n_estimators=50;, score=0.609 total time=   0.4s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=10, n_estimators=60;, score=0.595 total time=   0.5s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=10, n_estimators=60;, score=0.626 total time=   0.5s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=10, n_estimators=60;, score=0.610 total time=   0.5s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=10, n_estimators=80;, score=0.600 total time=   0.7s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=10, n_estimators=80;, score=0.627 total time=   0.7s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=10, n_estimators=80;, score=0.613 total time=   0.7s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=15, n_estimators=50;, score=0.597 total time=   0.4s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=15, n_estimators=50;, score=0.628 total time=   0.4s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=15, n_estimators=50;, score=0.605 total time=   0.4s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=15, n_estimators=60;, score=0.595 total time=   0.5s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=15, n_estimators=60;, score=0.624 total time=   0.5s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=15, n_estimators=60;, score=0.613 total time=   0.5s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=15, n_estimators=80;, score=0.603 total time=   0.7s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=15, n_estimators=80;, score=0.626 total time=   0.7s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=15, n_estimators=80;, score=0.611 total time=   0.7s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=20, n_estimators=50;, score=0.595 total time=   0.4s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=20, n_estimators=50;, score=0.625 total time=   0.4s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=20, n_estimators=50;, score=0.608 total time=   0.4s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=20, n_estimators=60;, score=0.593 total time=   0.6s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=20, n_estimators=60;, score=0.623 total time=   0.5s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=20, n_estimators=60;, score=0.613 total time=   0.5s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=20, n_estimators=80;, score=0.602 total time=   0.7s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=20, n_estimators=80;, score=0.625 total time=   0.7s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=20, n_estimators=80;, score=0.614 total time=   0.7s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=0.658 total time=   0.6s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=0.684 total time=   0.6s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=50;, score=0.672 total time=   0.6s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=60;, score=0.654 total time=   0.8s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=60;, score=0.690 total time=   0.8s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=60;, score=0.673 total time=   0.8s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=80;, score=0.659 total time=   1.1s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=80;, score=0.692 total time=   1.0s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=80;, score=0.677 total time=   1.1s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=0.655 total time=   0.6s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=0.680 total time=   0.6s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=0.677 total time=   0.6s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=60;, score=0.657 total time=   0.9s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=60;, score=0.686 total time=   0.8s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=60;, score=0.675 total time=   0.8s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=80;, score=0.661 total time=   1.0s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=80;, score=0.692 total time=   1.0s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=80;, score=0.675 total time=   1.1s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=15, n_estimators=50;, score=0.654 total time=   0.6s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=15, n_estimators=50;, score=0.687 total time=   0.6s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=15, n_estimators=50;, score=0.669 total time=   0.6s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=15, n_estimators=60;, score=0.651 total time=   0.7s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=15, n_estimators=60;, score=0.686 total time=   0.8s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=15, n_estimators=60;, score=0.671 total time=   0.9s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=15, n_estimators=80;, score=0.655 total time=   1.2s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=15, n_estimators=80;, score=0.686 total time=   1.1s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=15, n_estimators=80;, score=0.671 total time=   1.1s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=50;, score=0.651 total time=   0.7s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=50;, score=0.679 total time=   0.6s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=50;, score=0.665 total time=   0.6s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=60;, score=0.648 total time=   0.7s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=60;, score=0.685 total time=   0.7s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=60;, score=0.667 total time=   0.7s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=80;, score=0.649 total time=   1.0s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=80;, score=0.683 total time=   1.0s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=20, n_estimators=80;, score=0.667 total time=   1.0s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=0.640 total time=   0.6s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=0.666 total time=   0.6s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=50;, score=0.656 total time=   0.6s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=60;, score=0.642 total time=   0.8s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=60;, score=0.676 total time=   0.8s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=60;, score=0.654 total time=   0.8s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=80;, score=0.640 total time=   1.0s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=80;, score=0.674 total time=   1.0s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=80;, score=0.657 total time=   1.0s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.639 total time=   0.6s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.673 total time=   0.6s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=50;, score=0.663 total time=   0.6s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=60;, score=0.643 total time=   0.7s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=60;, score=0.673 total time=   0.7s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=60;, score=0.661 total time=   0.7s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=80;, score=0.635 total time=   1.0s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=80;, score=0.674 total time=   1.0s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=80;, score=0.659 total time=   1.0s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=15, n_estimators=50;, score=0.641 total time=   0.6s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=15, n_estimators=50;, score=0.671 total time=   0.6s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=15, n_estimators=50;, score=0.661 total time=   0.6s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=15, n_estimators=60;, score=0.637 total time=   0.7s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=15, n_estimators=60;, score=0.671 total time=   0.7s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=15, n_estimators=60;, score=0.661 total time=   0.7s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=15, n_estimators=80;, score=0.644 total time=   1.0s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=15, n_estimators=80;, score=0.674 total time=   1.0s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=15, n_estimators=80;, score=0.659 total time=   1.0s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=50;, score=0.640 total time=   0.6s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=50;, score=0.672 total time=   0.6s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=50;, score=0.657 total time=   0.6s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=60;, score=0.641 total time=   0.7s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=60;, score=0.676 total time=   0.7s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=60;, score=0.662 total time=   0.7s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=80;, score=0.644 total time=   1.0s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=80;, score=0.675 total time=   1.0s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=20, n_estimators=80;, score=0.657 total time=   1.0s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=15, min_samples_split=5, n_estimators=50;, score=0.626 total time=   0.6s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=15, min_samples_split=5, n_estimators=50;, score=0.660 total time=   0.6s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=15, min_samples_split=5, n_estimators=50;, score=0.643 total time=   0.6s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=15, min_samples_split=5, n_estimators=60;, score=0.625 total time=   0.7s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=15, min_samples_split=5, n_estimators=60;, score=0.665 total time=   0.7s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=15, min_samples_split=5, n_estimators=60;, score=0.643 total time=   0.7s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=15, min_samples_split=5, n_estimators=80;, score=0.629 total time=   0.9s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=15, min_samples_split=5, n_estimators=80;, score=0.657 total time=   1.0s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=15, min_samples_split=5, n_estimators=80;, score=0.643 total time=   0.9s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=15, min_samples_split=10, n_estimators=50;, score=0.623 total time=   0.6s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=15, min_samples_split=10, n_estimators=50;, score=0.658 total time=   0.6s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=15, min_samples_split=10, n_estimators=50;, score=0.645 total time=   0.6s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=15, min_samples_split=10, n_estimators=60;, score=0.621 total time=   0.7s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=15, min_samples_split=10, n_estimators=60;, score=0.664 total time=   0.7s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=15, min_samples_split=10, n_estimators=60;, score=0.641 total time=   0.7s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=15, min_samples_split=10, n_estimators=80;, score=0.624 total time=   0.9s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=15, min_samples_split=10, n_estimators=80;, score=0.662 total time=   1.0s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=15, min_samples_split=10, n_estimators=80;, score=0.645 total time=   0.9s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=15, min_samples_split=15, n_estimators=50;, score=0.631 total time=   0.6s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=15, min_samples_split=15, n_estimators=50;, score=0.661 total time=   0.6s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=15, min_samples_split=15, n_estimators=50;, score=0.639 total time=   0.6s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=15, min_samples_split=15, n_estimators=60;, score=0.626 total time=   0.7s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=15, min_samples_split=15, n_estimators=60;, score=0.662 total time=   0.7s
# [CV 3/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=15, min_samples_split=15, n_estimators=60;, score=0.643 total time=   0.7s
# [CV 1/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=15, min_samples_split=15, n_estimators=80;, score=0.625 total time=   0.9s
# [CV 2/3] END criterion=mse, max_depth=10, max_features=log2, min_samples_leaf=15, min_samples_split=15, n_estimators=80;, score=0.659 total time=   1.3s
# ...
# [CV 3/3] END criterion=mae, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=5, n_estimators=80;, score=0.696 total time= 4.3min
# [CV 1/3] END criterion=mae, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=0.665 total time= 2.7min
# [CV 2/3] END criterion=mae, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=0.706 total time= 2.8min
# [CV 3/3] END criterion=mae, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=50;, score=0.694 total time= 2.7min
# [CV 1/3] END criterion=mae, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=60;, score=0.667 total time= 3.2min
# [CV 2/3] END criterion=mae, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=60;, score=0.704 total time= 3.2min
# [CV 3/3] END criterion=mae, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=60;, score=0.692 total time= 3.2min
# [CV 1/3] END criterion=mae, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=80;, score=0.670 total time= 4.4min
# [CV 2/3] END criterion=mae, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=80;, score=0.709 total time= 4.3min
# [CV 3/3] END criterion=mae, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=80;, score=0.692 total time= 4.3min
# [CV 1/3] END criterion=mae, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=50;, score=0.662 total time= 2.7min
# [CV 2/3] END criterion=mae, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=50;, score=0.703 total time= 2.7min
# [CV 3/3] END criterion=mae, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=50;, score=0.691 total time= 2.7min
# [CV 1/3] END criterion=mae, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=60;, score=0.670 total time= 3.2min
# [CV 2/3] END criterion=mae, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=60;, score=0.700 total time= 3.2min
# [CV 3/3] END criterion=mae, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=60;, score=0.689 total time= 3.2min
# [CV 1/3] END criterion=mae, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=80;, score=0.667 total time= 4.4min
# [CV 2/3] END criterion=mae, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=80;, score=0.704 total time= 4.3min
# [CV 3/3] END criterion=mae, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=15, n_estimators=80;, score=0.686 total time= 4.3min
# [CV 1/3] END criterion=mae, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=20, n_estimators=50;, score=0.659 total time= 2.7min
# [CV 2/3] END criterion=mae, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=20, n_estimators=50;, score=0.697 total time= 2.7min
# [CV 3/3] END criterion=mae, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=20, n_estimators=50;, score=0.686 total time= 2.7min
# [CV 1/3] END criterion=mae, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=20, n_estimators=60;, score=0.663 total time= 3.2min
# [CV 2/3] END criterion=mae, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=20, n_estimators=60;, score=0.697 total time= 3.2min
# [CV 3/3] END criterion=mae, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=20, n_estimators=60;, score=0.687 total time= 3.2min
# [CV 1/3] END criterion=mae, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=20, n_estimators=80;, score=0.664 total time= 4.3min
# [CV 2/3] END criterion=mae, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=20, n_estimators=80;, score=0.700 total time= 4.5min
# [CV 3/3] END criterion=mae, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=20, n_estimators=80;, score=0.684 total time= 7.4min
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 GCV.fit(X_train,Y_train)
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:891, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     885     results = self._format_results(
#     886         all_candidate_params, n_splits, all_out, all_more_results
#     887     )
#     889     return results
# --> 891 self._run_search(evaluate_candidates)
#     893 # multimetric is determined here because in the case of a callable
#     894 # self.scoring the return type is only known after calling
#     895 first_test_score = all_out[0]["test_scores"]
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:1392, in GridSearchCV._run_search(self, evaluate_candidates)
#    1390 def _run_search(self, evaluate_candidates):
#    1391     """Search all candidates in param_grid"""
# -> 1392     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:838, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     830 if self.verbose > 0:
#     831     print(
#     832         "Fitting {0} folds for each of {1} candidates,"
#     833         " totalling {2} fits".format(
#     834             n_splits, n_candidates, n_candidates * n_splits
#     835         )
#     836     )
# --> 838 out = parallel(
#     839     delayed(_fit_and_score)(
#     840         clone(base_estimator),
#     841         X,
#     842         y,
#     843         train=train,
#     844         test=test,
#     845         parameters=parameters,
#     846         split_progress=(split_idx, n_splits),
#     847         candidate_progress=(cand_idx, n_candidates),
#     848         **fit_and_score_kwargs,
#     849     )
#     850     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     851         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     852     )
#     853 )
#     855 if len(out) < 1:
#     856     raise ValueError(
#     857         "No fits were performed. "
#     858         "Was the CV iterator empty? "
#     859         "Were there no candidates?"
#     860     )
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:1046, in Parallel.__call__(self, iterable)
#    1043 if self.dispatch_one_batch(iterator):
#    1044     self._iterating = self._original_iterator is not None
# -> 1046 while self.dispatch_one_batch(iterator):
#    1047     pass
#    1049 if pre_dispatch == "all" or n_jobs == 1:
#    1050     # The iterable was consumed all at once by the above for loop.
#    1051     # No need to wait for async callbacks to trigger to
#    1052     # consumption.
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:861, in Parallel.dispatch_one_batch(self, iterator)
#     859     return False
#     860 else:
# --> 861     self._dispatch(tasks)
#     862     return True
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:779, in Parallel._dispatch(self, batch)
#     777 with self._lock:
#     778     job_idx = len(self._jobs)
# --> 779     job = self._backend.apply_async(batch, callback=cb)
#     780     # A job can complete so quickly than its callback is
#     781     # called before we get here, causing self._jobs to
#     782     # grow. To ensure correct results ordering, .insert is
#     783     # used (rather than .append) in the following line
#     784     self._jobs.insert(job_idx, job)
#
# File ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:262, in BatchedCalls.__call__(self)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:262, in <listcomp>(.0)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\fixes.py:216, in _FuncWrapper.__call__(self, *args, **kwargs)
#     214 def __call__(self, *args, **kwargs):
#     215     with config_context(**self.config):
# --> 216         return self.function(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:680, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     678         estimator.fit(X_train, **fit_params)
#     679     else:
# --> 680         estimator.fit(X_train, y_train, **fit_params)
#     682 except Exception:
#     683     # Note fit time as time until error
#     684     fit_time = time.time() - start_time
#
# File ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:450, in BaseForest.fit(self, X, y, sample_weight)
#     439 trees = [
#     440     self._make_estimator(append=False, random_state=random_state)
#     441     for i in range(n_more_estimators)
#     442 ]
#     444 # Parallel loop: we prefer the threading backend as the Cython code
#     445 # for fitting the trees is internally releasing the Python GIL
#     446 # making threading more efficient than multiprocessing in
#     447 # that case. However, for joblib 0.12+ we respect any
#     448 # parallel_backend contexts set at a higher level,
#     449 # since correctness does not rely on using threads.
# --> 450 trees = Parallel(
#     451     n_jobs=self.n_jobs,
#     452     verbose=self.verbose,
#     453     **_joblib_parallel_args(prefer="threads"),
#     454 )(
#     455     delayed(_parallel_build_trees)(
#     456         t,
#     457         self,
#     458         X,
#     459         y,
#     460         sample_weight,
#     461         i,
#     462         len(trees),
#     463         verbose=self.verbose,
#     464         class_weight=self.class_weight,
#     465         n_samples_bootstrap=n_samples_bootstrap,
#     466     )
#     467     for i, t in enumerate(trees)
#     468 )
#     470 # Collect newly grown trees
#     471 self.estimators_.extend(trees)
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:1046, in Parallel.__call__(self, iterable)
#    1043 if self.dispatch_one_batch(iterator):
#    1044     self._iterating = self._original_iterator is not None
# -> 1046 while self.dispatch_one_batch(iterator):
#    1047     pass
#    1049 if pre_dispatch == "all" or n_jobs == 1:
#    1050     # The iterable was consumed all at once by the above for loop.
#    1051     # No need to wait for async callbacks to trigger to
#    1052     # consumption.
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:861, in Parallel.dispatch_one_batch(self, iterator)
#     859     return False
#     860 else:
# --> 861     self._dispatch(tasks)
#     862     return True
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:779, in Parallel._dispatch(self, batch)
#     777 with self._lock:
#     778     job_idx = len(self._jobs)
# --> 779     job = self._backend.apply_async(batch, callback=cb)
#     780     # A job can complete so quickly than its callback is
#     781     # called before we get here, causing self._jobs to
#     782     # grow. To ensure correct results ordering, .insert is
#     783     # used (rather than .append) in the following line
#     784     self._jobs.insert(job_idx, job)
#
# File ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:262, in BatchedCalls.__call__(self)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:262, in <listcomp>(.0)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\fixes.py:216, in _FuncWrapper.__call__(self, *args, **kwargs)
#     214 def __call__(self, *args, **kwargs):
#     215     with config_context(**self.config):
# --> 216         return self.function(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:185, in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     182     elif class_weight == "balanced_subsample":
#     183         curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
# --> 185     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     186 else:
#     187     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# File ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py:1315, in DecisionTreeRegressor.fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1278 def fit(
#    1279     self, X, y, sample_weight=None, check_input=True, X_idx_sorted="deprecated"
#    1280 ):
#    1281     """Build a decision tree regressor from the training set (X, y).
#    1282
#    1283     Parameters
#    (...)
#    1312         Fitted estimator.
#    1313     """
# -> 1315     super().fit(
#    1316         X,
#    1317         y,
#    1318         sample_weight=sample_weight,
#    1319         check_input=check_input,
#    1320         X_idx_sorted=X_idx_sorted,
#    1321     )
#    1322     return self
#
# File ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py:420, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     409 else:
#     410     builder = BestFirstTreeBuilder(
#     411         splitter,
#     412         min_samples_split,
#    (...)
#     417         self.min_impurity_decrease,
#     418     )
# --> 420 builder.build(self.tree_, X, y, sample_weight)
#     422 if self.n_outputs_ == 1 and is_classifier(self):
#     423     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
from sklearn.ensemble import RandomForestRegressor
Final_mod =  RandomForestRegressor(n_estimators=80 ,criterion = 'mse', max_depth= 40, max_features = 'sqrt',
             min_samples_leaf = 5, min_samples_split = 10)
Final_mod.fit(X_train,Y_train)
y_pred=Final_mod.predict(X_test)

print('\033[1m'+' R2 Score of Final Model :'+'\033[0m')
print(r2_score(Y_test,y_pred)) 
print('\n')
# Out:
#  R2 Score of Final Model :
# 0.7338739030180315

# %%
plt.figure(figsize=(12,7))
y_pred=Final_mod.predict(X_test)
sns.swarmplot(Y_test.round(2), y_pred)
print('\033[1m'+' True Values Vs Predicted Value plot :' +'\033[0m')
plt.xlabel('True Values' , fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.tight_layout()
# Out:
#  True Values Vs Predicted Value plot :

# %%
import joblib
joblib.dump(Final_mod,'avacado_regression_Final.pkl')
# Out:
# ['avacado_regression_Final.pkl']
